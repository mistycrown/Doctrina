# %%
import os
from PyPDF2 import PdfReader, PdfWriter

def get_bookmark_page_number(reader, bookmark):
    """获取书签对应的页码"""
    try:
        return reader.get_destination_page_number(bookmark)
    except:
        try:
            # 尝试直接从页面对象获取页码
            if '/Page' in bookmark:
                page_ref = bookmark['/Page']
                for i, page in enumerate(reader.pages):
                    if page.indirect_reference == page_ref:
                        return i
        except:
            pass
    return None

def extract_bookmarks_recursive(reader):
    """提取所有书签"""
    bookmarks_list = []
    
    def process_bookmark(bookmark, level=0, parent=""):
        if isinstance(bookmark, dict):
            title = bookmark.get('/Title', 'Untitled')
            full_title = f"{parent} - {title}" if parent else title
            
            # 获取页码
            page_num = get_bookmark_page_number(reader, bookmark)
            if page_num is not None:
                print(f"找到书签: {full_title} (层级: {level}, 页码: {page_num})")
                bookmarks_list.append({
                    'title': full_title,
                    'page': page_num,
                    'level': level
                })
            else:
                print(f"警告：无法获取书签页码: {full_title}")
            
            # 处理子书签
            if '/First' in bookmark:
                process_bookmark(bookmark['/First'], level + 1, full_title)
            # 处理同级书签
            if '/Next' in bookmark:
                process_bookmark(bookmark['/Next'], level, parent)
        elif isinstance(bookmark, list):
            for b in bookmark:
                process_bookmark(b, level, parent)
    
    # 处理根书签
    outline = reader.outline
    if isinstance(outline, list):
        for item in outline:
            process_bookmark(item)
    else:
        process_bookmark(outline)
    
    return bookmarks_list

def split_pdf_by_bookmarks(input_pdf, output_dir, target_level=0):
    """根据指定层级的书签切分PDF文件"""
    print(f"正在处理PDF文件: {input_pdf}")
    print(f"输出目录: {output_dir}")
    print(f"目标书签层级: {target_level}")
    
    # 确保输出目录存在
    os.makedirs(output_dir, exist_ok=True)
    
    # 读取PDF
    reader = PdfReader(input_pdf)
    print(f"PDF总页数: {len(reader.pages)}")
    
    # 获取所有书签
    all_bookmarks = extract_bookmarks_recursive(reader)
    
    if not all_bookmarks:
        print("未找到任何书签！")
        return
    
    # 筛选指定层级的书签
    target_bookmarks = [b for b in all_bookmarks if b['level'] == target_level]
    
    if not target_bookmarks:
        print(f"没有找到{target_level}级书签！")
        print("可用的书签层级:")
        levels = sorted(set(b['level'] for b in all_bookmarks))
        for level in levels:
            count = sum(1 for b in all_bookmarks if b['level'] == level)
            print(f"层级 {level}: {count} 个书签")
        return
    
    print(f"\n找到 {len(target_bookmarks)} 个目标层级书签:")
    for i, b in enumerate(target_bookmarks):
        print(f"{i+1}. {b['title']} (页码: {b['page']})")
    
    # 按书签切分PDF
    for i in range(len(target_bookmarks)):
        writer = PdfWriter()
        current = target_bookmarks[i]
        
        # 确定页码范围
        start_page = current['page']
        if i < len(target_bookmarks) - 1:
            end_page = target_bookmarks[i + 1]['page']
        else:
            end_page = len(reader.pages)
        
        print(f"\n正在处理 '{current['title']}'")
        print(f"页码范围: {start_page} 到 {end_page-1}")
        
        # 复制页面
        try:
            for page_num in range(start_page, end_page):
                if page_num < len(reader.pages):
                    writer.add_page(reader.pages[page_num])
                    print(f"已添加页面 {page_num}", end='\r')
            
            # 生成文件名
            safe_title = "".join(c for c in current['title'] if c.isalnum() or c in (' ', '-', '_'))
            output_file = os.path.join(output_dir, f"{i+1:03d}-{safe_title}.pdf")
            
            # 保存文件
            with open(output_file, 'wb') as output:
                writer.write(output)
            print(f"\n已创建: {output_file}")
        except Exception as e:
            print(f"处理文件时出错: {e}")

if __name__ == "__main__":
    input_pdf = "文化研究关键词 - 汪民安.pdf"
    output_dir = "split_pdfs"
    
    # 使用层级 0 来切分（对应第一级书签）
    split_pdf_by_bookmarks(input_pdf, output_dir, target_level=0)
# Out:
# 正在处理PDF文件: 文化研究关键词 - 汪民安.pdf
# 输出目录: split_pdfs
# 目标书签层级: 0
# PDF总页数: 946
# 找到书签: 版权信息 (层级: 0, 页码: 1)
# 找到书签: 修订版前言 (层级: 0, 页码: 11)
# 找到书签: 前言：词语的深渊 (层级: 0, 页码: 13)
# 找到书签: B (层级: 0, 页码: 18)
# 找到书签: 保守主义（Conservatism） (层级: 0, 页码: 18)
# 找到书签: 暴力（Violence） (层级: 0, 页码: 24)
# 找到书签: 辩证法（Dialectic） (层级: 0, 页码: 28)
# 找到书签: 辩证意象（Dialectic Image） (层级: 0, 页码: 30)
# 找到书签: C (层级: 0, 页码: 34)
# 找到书签: 擦抹（Under Erasure） (层级: 0, 页码: 34)
# 找到书签: 残酷戏剧（le théatre de la cruauté） (层级: 0, 页码: 38)
# 找到书签: 策略性本质主义（Strategic Essentialism） (层级: 0, 页码: 43)
# 找到书签: 差异（Difference） (层级: 0, 页码: 47)
# 找到书签: 场域（Field） (层级: 0, 页码: 53)
# 找到书签: 超人（übermensch） (层级: 0, 页码: 57)
# 找到书签: 超真实（Hyperreal） (层级: 0, 页码: 60)
# 找到书签: 赤裸生命（Bare Life） (层级: 0, 页码: 64)
# 找到书签: 词语误用（Catachresis） (层级: 0, 页码: 68)
# 找到书签: 存在（Being） (层级: 0, 页码: 71)
# 找到书签: 存在主义（Existentialism） (层级: 0, 页码: 76)
# 找到书签: D (层级: 0, 页码: 80)
# 找到书签: 单面人（OneDimensionalMan） (层级: 0, 页码: 80)
# 找到书签: 单子（Monad） (层级: 0, 页码: 84)
# 找到书签: 地方性知识（Local Knowledge） (层级: 0, 页码: 87)
# 找到书签: 帝国（Empire） (层级: 0, 页码: 90)
# 找到书签: 第三空间（Third Space） (层级: 0, 页码: 95)
# 找到书签: 东方主义（Orientalism） (层级: 0, 页码: 100)
# 找到书签: 动物（The Animal） (层级: 0, 页码: 104)
# 找到书签: 多元文化主义（Multiculturalism） (层级: 0, 页码: 109)
# 找到书签: E (层级: 0, 页码: 113)
# 找到书签: 俄狄浦斯情结（Complexe d'Oedipe） (层级: 0, 页码: 113)
# 找到书签: F (层级: 0, 页码: 116)
# 找到书签: 反本质主义（Anti-Essentialism） (层级: 0, 页码: 116)
# 找到书签: 反俄狄浦斯（Anti-Oedipus） (层级: 0, 页码: 121)
# 找到书签: 仿真（Simulacra） (层级: 0, 页码: 126)
# 找到书签: 菲勒斯（Phallus） (层级: 0, 页码: 130)
# 13. 差异（Difference） (页码: 47)
# 14. 场域（Field） (页码: 53)
# 15. 超人（übermensch） (页码: 57)
# 16. 超真实（Hyperreal） (页码: 60)
# 17. 赤裸生命（Bare Life） (页码: 64)
# 18. 词语误用（Catachresis） (页码: 68)
# 19. 存在（Being） (页码: 71)
# 20. 存在主义（Existentialism） (页码: 76)
# 21. D (页码: 80)
# 22. 单面人（OneDimensionalMan） (页码: 80)
# 23. 单子（Monad） (页码: 84)
# 24. 地方性知识（Local Knowledge） (页码: 87)
# 25. 帝国（Empire） (页码: 90)
# 26. 第三空间（Third Space） (页码: 95)
# 27. 东方主义（Orientalism） (页码: 100)
# 28. 动物（The Animal） (页码: 104)
# 29. 多元文化主义（Multiculturalism） (页码: 109)
# 30. E (页码: 113)
# 31. 俄狄浦斯情结（Complexe d'Oedipe） (页码: 113)
# 32. F (页码: 116)
# 33. 反本质主义（Anti-Essentialism） (页码: 116)
# 34. 反俄狄浦斯（Anti-Oedipus） (页码: 121)
# 35. 仿真（Simulacra） (页码: 126)
# 36. 菲勒斯（Phallus） (页码: 130)
# 37. 分裂分析（Schizoanalysis） (页码: 134)
# 38. 否定辩证法（Negative Dialectics） (页码: 138)
# 39. 福特主义/后福特主义（Fordism /Post-fordism） (页码: 143)
# 40. 父权（Patriarchy） (页码: 146)
# 41. 复调理论（Polyphonic Theory） (页码: 151)
# 42. G (页码: 155)
# 43. 感性分配（Le partage du sensible） (页码: 155)
# 44. 革命（Revolution） (页码: 160)
# 45. 工具理性（Instrumental Reason） (页码: 165)
# 46. 公共领域（PublicSphere） (页码: 168)
# 47. 怪怖（Unheimliche） (页码: 172)
# 48. 光晕（Aura） (页码: 177)
# 49. 规训（Discipline） (页码: 181)
# 50. 过度决定（Overdetermination） (页码: 184)
# 51. H (页码: 188)
# 52. 耗费（Expenditure） (页码: 188)
# 53. 合法性（Legitimacy） (页码: 192)
# 54. 宏大叙事（Grand Narrative） (页码: 197)
# 55. 后结构主义（Post-Structuralism） (页码: 201)
# 56. 后人类（Posthuman） (页码: 206)
# 57. 后殖民/后殖民主义（Post-Colonial / Post-Colonialism） (页码: 211)
# 58. 互文性（Intertextuality） (页码: 215)
# 59. 混杂性（Hybridity） (页码: 219)
# 60. 货币哲学（The Philosophy of Money） (页码: 222)
# 61. J (页码: 225)
# 62. 机械复制（Technische Reproduzierbarkeit） (页码: 225)
# 63. 集体无意识（Collective Unconsciousness） (页码: 229)
# 64. 加速主义（Accelerationism） (页码: 232)
# 65. 价值（Value） (页码: 236)
# 66. 间离（Verfremdung） (页码: 239)
# 67. 交往理性（Communicative Rationality） (页码: 243)
# 68. 阶级（Class） (页码: 248)
# 69. 姐妹情谊（Sisterhood） (页码: 251)
# 70. 解构（Deconstruction） (页码: 255)
# 71. 解构的伦理学（the Ethics of Deconstruction） (页码: 260)
# 72. 解释学（Hermeneutics） (页码: 264)
# 73. 解辖域化（Deterritorialisation） (页码: 267)
# 74. 景观社会（the Society of the Spectacle） (页码: 270)
# 75. 镜像阶段（the Mirror Stage） (页码: 273)
# 76. 救赎（Redemption） (页码: 277)
# 77. 绝境（Aporias） (页码: 281)
# 78. K (页码: 288)
# 79. 客体导向本体论（Ontology of object orientation） (页码: 288)
# 80. 空间（Space） (页码: 293)
# 81. 空间生产（Production of Space） (页码: 298)
# 82. 空间正义（Spatial Justice） (页码: 301)
# 83. 块茎（Rhizome） (页码: 305)
# 84. 快感（Pleasure） (页码: 310)
# 85. 狂欢（Carnival） (页码: 313)
# 86. L (页码: 317)
# 87. 浪荡子（Flaneur） (页码: 317)
# 88. 礼物（Gift） (页码: 321)
# 89. 理论（Theory） (页码: 324)
# 90. 理性（Reason, Vernunft） (页码: 328)
# 91. 零度写作（Writing Degree Zero） (页码: 332)
# 92. 逻各斯中心主义（Logocentrism） (页码: 336)
# 93. M (页码: 341)
# 94. 绵延（Duration） (页码: 341)
# 95. 免疫（Immune） (页码: 345)
# 96. 民族—国家（Nation-State） (页码: 349)
# 97. 民族志（Ethnography） (页码: 352)
# 98. 模拟（Mimicry） (页码: 356)
# 99. 陌生化（Oстранение） (页码: 359)
# 100. N (页码: 363)
# 101. 内爆（Implosion） (页码: 363)
# 102. 内在/超越（Immanent/Transcendent） (页码: 367)
# 103. 男性中心主义（Androcentrism） (页码: 372)
# 104. 能指（Singifier） (页码: 376)
# 105. 拟像（Simulation） (页码: 380)
# 106. 女性奥秘论（Feminine Mystique） (页码: 383)
# 107. 女性气质（Femininity） (页码: 387)
# 108. 女性主义（Feminism） (页码: 391)
# 109. P (页码: 395)
# 110. 批判理论（Critical Theory） (页码: 395)
# 111. 普遍性/普遍主义（Universality/Universalism） (页码: 400)
# 112. 谱系学（Genealogy） (页码: 403)
# 113. Q (页码: 407)
# 114. 歧义/歧见（mésentente） (页码: 407)
# 115. 奇异性（singularity） (页码: 411)
# 116. 启蒙（Enlightenment） (页码: 415)
# 117. 启蒙辩证法（Dialectic of Enlightenment） (页码: 420)
# 118. 千高原（A Thousand Plateaus） (页码: 424)
# 119. 潜能（Potentiality） (页码: 428)
# 120. 潜在（Virtual） (页码: 431)
# 121. 强度（Intensity） (页码: 436)
# 122. 情动/情感（affect） (页码: 440)
# 123. 情感结构（Structures of Feeling） (页码: 445)
# 124. 全景敞视主义（Panopticism） (页码: 448)
# 125. 权力（Power） (页码: 452)
# 126. 权力意志（Will to Power） (页码: 455)
# 127. 权力—知识（Power-Knowledge） (页码: 459)
# 128. R (页码: 464)
# 129. 人类纪（Anthropocene） (页码: 464)
# 130. 人文主义（Humanism） (页码: 468)
# 131. 人之死（Death of Men） (页码: 472)
# 132. 认识论断裂（Epistemological Rupture） (页码: 476)
# 133. 认知暴力（Epistemic Violence） (页码: 479)
# 134. 认知图绘（Cognitive Mapping） (页码: 483)
# 135. 日常生活（Everyday Life） (页码: 486)
# 136. S (页码: 491)
# 137. 赛博格（cyborg） (页码: 491)
# 138. 赛博空间（Cyberspace） (页码: 495)
# 139. 商品拜物教（Commodity Fetishism） (页码: 498)
# 140. 上帝之死（God's Death） (页码: 504)
# 141. 社群（Community） (页码: 508)
# 142. 身份/认同（Identity） (页码: 511)
# 143. 身体（body） (页码: 515)
# 144. 深描（Thick Description） (页码: 519)
# 145. 神话/神话学（Myth/Mythology） (页码: 522)
# 146. 神话—原型（Mythic-Archetypal） (页码: 525)
# 147. 神圣人（homo sacer） (页码: 529)
# 148. 审美（Aesthetic） (页码: 534)
# 149. 生成（Becoming） (页码: 537)
# 150. 生命权力/生命政治（Biopower/Biopolitics） (页码: 542)
# 151. 生态文学（Ecological Literature） (页码: 546)
# 152. 时间/时间-空间（Time/ Time-Space） (页码: 551)
# 153. 时空压缩（Time-Space Compression） (页码: 555)
# 154. 事件（Event） (页码: 559)
# 155. 世界体系（World-System） (页码: 563)
# 156. 世俗的启迪（Profane Illumination） (页码: 568)
# 157. 市民社会（Civil Society） (页码: 572)
# 158. 属下/属下阶层（Subaltern） (页码: 576)
# 159. 述行（Performative） (页码: 579)
# 160. 双性同体（Androgyny） (页码: 582)
# 161. 碎片（Fragments） (页码: 586)
# 162. 所指（Signified） (页码: 590)
# 163. T (页码: 593)
# 164. 他人/他者（autre/Autre） (页码: 593)
# 165. 逃逸线（ligne de fuite） (页码: 596)
# 166. 同质性/异质性（Homogeneity/Heterogeneity） (页码: 600)
# 167. W (页码: 604)
# 168. 晚期资本主义（Late Capitalism） (页码: 604)
# 169. 文本（Text） (页码: 608)
# 170. 文化霸权（Hegemony） (页码: 612)
# 171. 文化帝国主义（Cultural Imperialism） (页码: 616)
# 172. 文化工业（Culture Industry） (页码: 620)
# 173. 文化记忆（Das kulturelle Gedächtnis） (页码: 625)
# 174. 文化唯物主义（Cultural Materialism） (页码: 629)
# 175. 文化研究（Cultural Studies） (页码: 634)
# 176. 文化政治（Cultural Politics） (页码: 638)
# 177. 文化资本（Cultural Capital） (页码: 643)
# 178. 无器官身体（Body without Organs） (页码: 647)
# 179. 无意识（Inconscient） (页码: 652)
# 180. 物化（Reification） (页码: 655)
# 181. 物质（Material） (页码: 659)
# 182. X (页码: 664)
# 183. 西方马克思主义（Western Marxism） (页码: 664)
# 184. 习性（Habitus） (页码: 668)
# 185. 戏仿（Parody） (页码: 672)
# 186. 现代性（Modernity） (页码: 677)
# 187. 现代主义（Modernism） (页码: 681)
# 188. 现象学（Phenomenology） (页码: 685)
# 189. 想象/象征/真实（the Imaginary/the Symbolic/the Real） (页码: 689)
# 190. 象征资本（Symbolic Capital） (页码: 694)
# 191. 消费社会（Consumer Society） (页码: 699)
# 192. 新教伦理（Protestant Ethic） (页码: 704)
# 193. 新历史主义（New Historicism, Neo-Historicism） (页码: 707)
# 194. 新物质主义（New Materialism） (页码: 710)
# 195. 星座（Constellation） (页码: 714)
# 196. 行动力/能动性（Agency） (页码: 718)
# 197. 行动者网络理论（Actor-Network Theory） (页码: 722)
# 198. 形而上学（Metaphysics） (页码: 727)
# 199. 形式主义（Formalism） (页码: 732)
# 200. 性别（Sex, Gender） (页码: 736)
# 201. 性别表演（Gender Performance） (页码: 740)
# 202. 性政治（Sexual Politics） (页码: 744)
# 203. 叙事学（Narratology） (页码: 748)
# 204. Y (页码: 752)
# 205. 延异（Différance） (页码: 752)
# 206. 言语行为理论（Speech Acts Theory） (页码: 758)
# 207. 厌女症（Misogyny） (页码: 761)
# 208. 移动性（Mobility） (页码: 765)
# 209. 仪式（Ritual） (页码: 770)
# 210. 异化（Alienation） (页码: 773)
# 211. 异托邦（Heterotopia） (页码: 776)
# 212. 意识形态（Ideology） (页码: 781)
# 213. 意识形态国家机器（Ideological State Apparatuses） (页码: 787)
# 214. 隐喻/转喻（Metaphor/Metonymy） (页码: 790)
# 215. 永恒轮回（Eternal Return） (页码: 795)
# 216. 忧郁（Melancholy） (页码: 799)
# 217. 游牧（Nomad） (页码: 802)
# 218. 有机知识分子（Organic Intellectuals） (页码: 806)
# 219. 语言转向（the Linguistic Turn） (页码: 809)
# 220. 语义学（Semantics） (页码: 813)
# 221. 欲望（Desire） (页码: 817)
# 222. 欲望机器（Desiring-Machines） (页码: 822)
# 223. 寓言（Allegory） (页码: 826)
# 224. 元历史（Metahistory） (页码: 830)
# 225. 元叙事（Metanarrative） (页码: 834)
# 226. 怨恨（Ressentiment） (页码: 837)
# 227. Z (页码: 841)
# 228. 在场/缺席（Presence/Absence） (页码: 841)
# 229. 褶子（Fold） (页码: 845)
# 230. 阵地战（War of Position） (页码: 850)
# 231. 震惊（Shock） (页码: 853)
# 232. 政治无意识（Political Unconscious） (页码: 856)
# 233. 症状阅读（Symptomatic Reading） (页码: 859)
# 234. 知识考古学（the Archeology of Knowledge） (页码: 863)
# 235. 知识型（épistèmé） (页码: 867)
# 236. 治理术（gouvernementalité） (页码: 871)
# 237. 诸众（Multitude） (页码: 875)
# 238. 主奴辩证法（the Dialectic of the Master and the Slave） (页码: 880)
# 239. 主权（Sovereignty） (页码: 885)
# 240. 主体/客体（Subject/Object） (页码: 888)
# 241. 装配/装置（agencement/dispositif） (页码: 893)
# 242. 资本/资本主义（Capital/Capitalism） (页码: 898)
# 243. 自然之镜（Mirror of Nature） (页码: 901)
# 244. 自我技术（Technologies of the Self） (页码: 904)
# 245. 自由（Freedom） (页码: 908)
# 246. 自由主义（Liberalism） (页码: 913)
# 247. 踪迹（Trace） (页码: 918)
# 248. 总体性（Totality） (页码: 923)
# 249. 族裔（Ethnicity） (页码: 927)
# 250. 作者之死（the Death of the Author） (页码: 930)
# 251. 术语对照表 (页码: 934)
#
# 正在处理 '版权信息'
# 页码范围: 1 到 10
# 已添加页面 10
# 已创建: split_pdfs\001-版权信息.pdf
#
# 正在处理 '修订版前言'
# 页码范围: 11 到 12
# 已添加页面 12
# 已创建: split_pdfs\002-修订版前言.pdf
#
# 正在处理 '前言：词语的深渊'
# 页码范围: 13 到 17
# 已添加页面 17
# 已创建: split_pdfs\003-前言词语的深渊.pdf
#
# 正在处理 'B'
# 页码范围: 18 到 17
#
# 已创建: split_pdfs\004-B.pdf
#
# 正在处理 '保守主义（Conservatism）'
# 页码范围: 18 到 23
# 已添加页面 23
# 已创建: split_pdfs\005-保守主义Conservatism.pdf
#
# 正在处理 '暴力（Violence）'
# 页码范围: 24 到 27
# 已添加页面 27
# 已创建: split_pdfs\006-暴力Violence.pdf
#
# 正在处理 '辩证法（Dialectic）'
# 页码范围: 28 到 29
# 已添加页面 29
# 已创建: split_pdfs\007-辩证法Dialectic.pdf
#
# 正在处理 '辩证意象（Dialectic Image）'
# 页码范围: 30 到 33
# 已添加页面 33
# 已创建: split_pdfs\008-辩证意象Dialectic Image.pdf
#
# 正在处理 'C'
# 页码范围: 34 到 33
#
# 已创建: split_pdfs\009-C.pdf
#
# 正在处理 '擦抹（Under Erasure）'
# 页码范围: 34 到 37
# 已添加页面 37
# 已创建: split_pdfs\010-擦抹Under Erasure.pdf
#
# 正在处理 '残酷戏剧（le théatre de la cruauté）'
# 页码范围: 38 到 42
# 已添加页面 42
# 已创建: split_pdfs\011-残酷戏剧le théatre de la cruauté.pdf
#
# 正在处理 '策略性本质主义（Strategic Essentialism）'
# 页码范围: 43 到 46
# 已添加页面 46
# 已创建: split_pdfs\012-策略性本质主义Strategic Essentialism.pdf
#
# 正在处理 '差异（Difference）'
# 页码范围: 47 到 52
# 已添加页面 52
# 已创建: split_pdfs\013-差异Difference.pdf
#
# 正在处理 '场域（Field）'
# 页码范围: 53 到 56
# 已添加页面 56
# 已创建: split_pdfs\014-场域Field.pdf
#
# 正在处理 '超人（übermensch）'
# 页码范围: 57 到 59
# 已添加页面 59
# 已创建: split_pdfs\015-超人übermensch.pdf
#
# 正在处理 '超真实（Hyperreal）'
# 页码范围: 60 到 63
# 已添加页面 63
# 已创建: split_pdfs\016-超真实Hyperreal.pdf
#
# 正在处理 '赤裸生命（Bare Life）'
# 页码范围: 64 到 67
# 已添加页面 67
# 已创建: split_pdfs\017-赤裸生命Bare Life.pdf
#
# 正在处理 '词语误用（Catachresis）'
# 页码范围: 68 到 70
# 已添加页面 70
# 已创建: split_pdfs\018-词语误用Catachresis.pdf
#
# 正在处理 '存在（Being）'
# 页码范围: 71 到 75
# 已添加页面 75
# 已创建: split_pdfs\019-存在Being.pdf
#
# 正在处理 '存在主义（Existentialism）'
# 页码范围: 76 到 79
# 已添加页面 79
# 已创建: split_pdfs\020-存在主义Existentialism.pdf
#
# 正在处理 'D'
# 页码范围: 80 到 79
#
# 已创建: split_pdfs\021-D.pdf
#
# 正在处理 '单面人（OneDimensionalMan）'
# 页码范围: 80 到 83
# 已添加页面 83
# 已创建: split_pdfs\022-单面人OneDimensionalMan.pdf
#
# 正在处理 '单子（Monad）'
# 页码范围: 84 到 86
# 已添加页面 86
# 已创建: split_pdfs\023-单子Monad.pdf
#
# 正在处理 '地方性知识（Local Knowledge）'
# 页码范围: 87 到 89
# 已添加页面 89
# 已创建: split_pdfs\024-地方性知识Local Knowledge.pdf
#
# 正在处理 '帝国（Empire）'
# 页码范围: 90 到 94
# 已添加页面 94
# 已创建: split_pdfs\025-帝国Empire.pdf
#
# 正在处理 '第三空间（Third Space）'
# 页码范围: 95 到 99
# 已添加页面 99
# 已创建: split_pdfs\026-第三空间Third Space.pdf
#
# 正在处理 '东方主义（Orientalism）'
# 页码范围: 100 到 103
# 已添加页面 103
# 已创建: split_pdfs\027-东方主义Orientalism.pdf
#
# 正在处理 '动物（The Animal）'
# 页码范围: 104 到 108
# 已添加页面 108
# 已创建: split_pdfs\028-动物The Animal.pdf
#
# 正在处理 '多元文化主义（Multiculturalism）'
# 页码范围: 109 到 112
# 已添加页面 112
# 已创建: split_pdfs\029-多元文化主义Multiculturalism.pdf
#
# 正在处理 'E'
# 页码范围: 113 到 112
#
# 已创建: split_pdfs\030-E.pdf
#
# 正在处理 '俄狄浦斯情结（Complexe d'Oedipe）'
# 页码范围: 113 到 115
# 已添加页面 115
# 已创建: split_pdfs\031-俄狄浦斯情结Complexe dOedipe.pdf
#
# 正在处理 'F'
# 页码范围: 116 到 115
#
# 已创建: split_pdfs\032-F.pdf
#
# 正在处理 '反本质主义（Anti-Essentialism）'
# 页码范围: 116 到 120
# 已添加页面 120
# 已创建: split_pdfs\033-反本质主义Anti-Essentialism.pdf
#
# 正在处理 '反俄狄浦斯（Anti-Oedipus）'
# 页码范围: 121 到 125
# 已添加页面 125
# 已创建: split_pdfs\034-反俄狄浦斯Anti-Oedipus.pdf
#
# 正在处理 '仿真（Simulacra）'
# 页码范围: 126 到 129
# 已添加页面 129
# 已创建: split_pdfs\035-仿真Simulacra.pdf
#
# 正在处理 '菲勒斯（Phallus）'
# 页码范围: 130 到 133
# 已添加页面 133
# 已创建: split_pdfs\036-菲勒斯Phallus.pdf
#
# 正在处理 '分裂分析（Schizoanalysis）'
# 页码范围: 134 到 137
# 已添加页面 137
# 已创建: split_pdfs\037-分裂分析Schizoanalysis.pdf
#
# 正在处理 '否定辩证法（Negative Dialectics）'
# 页码范围: 138 到 142
# 已添加页面 142
# 已创建: split_pdfs\038-否定辩证法Negative Dialectics.pdf
#
# 正在处理 '福特主义/后福特主义（Fordism /Post-fordism）'
# 页码范围: 143 到 145
# 已添加页面 145
# 已创建: split_pdfs\039-福特主义后福特主义Fordism Post-fordism.pdf
#
# 正在处理 '父权（Patriarchy）'
# 页码范围: 146 到 150
# 已添加页面 150
# 已创建: split_pdfs\040-父权Patriarchy.pdf
#
# 正在处理 '复调理论（Polyphonic Theory）'
# 页码范围: 151 到 154
# 已添加页面 154
# 已创建: split_pdfs\041-复调理论Polyphonic Theory.pdf
#
# 正在处理 'G'
# 页码范围: 155 到 154
#
# 已创建: split_pdfs\042-G.pdf
#
# 正在处理 '感性分配（Le partage du sensible）'
# 页码范围: 155 到 159
# 已添加页面 159
# 已创建: split_pdfs\043-感性分配Le partage du sensible.pdf
#
# 正在处理 '革命（Revolution）'
# 页码范围: 160 到 164
# 已添加页面 164
# 已创建: split_pdfs\044-革命Revolution.pdf
#
# 正在处理 '工具理性（Instrumental Reason）'
# 页码范围: 165 到 167
# 已添加页面 167
# 已创建: split_pdfs\045-工具理性Instrumental Reason.pdf
#
# 正在处理 '公共领域（PublicSphere）'
# 页码范围: 168 到 171
# 已添加页面 171
# 已创建: split_pdfs\046-公共领域PublicSphere.pdf
#
# 正在处理 '怪怖（Unheimliche）'
# 页码范围: 172 到 176
# 已添加页面 176
# 已创建: split_pdfs\047-怪怖Unheimliche.pdf
#
# 正在处理 '光晕（Aura）'
# 页码范围: 177 到 180
# 已添加页面 180
# 已创建: split_pdfs\048-光晕Aura.pdf
#
# 正在处理 '规训（Discipline）'
# 页码范围: 181 到 183
# 已添加页面 183
# 已创建: split_pdfs\049-规训Discipline.pdf
#
# 正在处理 '过度决定（Overdetermination）'
# 页码范围: 184 到 187
# 已添加页面 187
# 已创建: split_pdfs\050-过度决定Overdetermination.pdf
#
# 正在处理 'H'
# 页码范围: 188 到 187
#
# 已创建: split_pdfs\051-H.pdf
#
# 正在处理 '耗费（Expenditure）'
# 页码范围: 188 到 191
# 已添加页面 191
# 已创建: split_pdfs\052-耗费Expenditure.pdf
#
# 正在处理 '合法性（Legitimacy）'
# 页码范围: 192 到 196
# 已添加页面 196
# 已创建: split_pdfs\053-合法性Legitimacy.pdf
#
# 正在处理 '宏大叙事（Grand Narrative）'
# 页码范围: 197 到 200
# 已添加页面 200
# 已创建: split_pdfs\054-宏大叙事Grand Narrative.pdf
#
# 正在处理 '后结构主义（Post-Structuralism）'
# 页码范围: 201 到 205
# 已添加页面 205
# 已创建: split_pdfs\055-后结构主义Post-Structuralism.pdf
#
# 正在处理 '后人类（Posthuman）'
# 页码范围: 206 到 210
# 已添加页面 210
# 已创建: split_pdfs\056-后人类Posthuman.pdf
#
# 正在处理 '后殖民/后殖民主义（Post-Colonial / Post-Colonialism）'
# 页码范围: 211 到 214
# 已添加页面 214
# 已创建: split_pdfs\057-后殖民后殖民主义Post-Colonial  Post-Colonialism.pdf
#
# 正在处理 '互文性（Intertextuality）'
# 页码范围: 215 到 218
# 已添加页面 218
# 已创建: split_pdfs\058-互文性Intertextuality.pdf
#
# 正在处理 '混杂性（Hybridity）'
# 页码范围: 219 到 221
# 已添加页面 221
# 已创建: split_pdfs\059-混杂性Hybridity.pdf
#
# 正在处理 '货币哲学（The Philosophy of Money）'
# 页码范围: 222 到 224
# 已添加页面 224
# 已创建: split_pdfs\060-货币哲学The Philosophy of Money.pdf
#
# 正在处理 'J'
# 页码范围: 225 到 224
#
# 已创建: split_pdfs\061-J.pdf
#
# 正在处理 '机械复制（Technische Reproduzierbarkeit）'
# 页码范围: 225 到 228
# 已添加页面 228
# 已创建: split_pdfs\062-机械复制Technische Reproduzierbarkeit.pdf
#
# 正在处理 '集体无意识（Collective Unconsciousness）'
# 页码范围: 229 到 231
# 已添加页面 231
# 已创建: split_pdfs\063-集体无意识Collective Unconsciousness.pdf
#
# 正在处理 '加速主义（Accelerationism）'
# 页码范围: 232 到 235
# 已添加页面 235
# 已创建: split_pdfs\064-加速主义Accelerationism.pdf
#
# 正在处理 '价值（Value）'
# 页码范围: 236 到 238
# 已添加页面 238
# 已创建: split_pdfs\065-价值Value.pdf
#
# 正在处理 '间离（Verfremdung）'
# 页码范围: 239 到 242
# 已添加页面 242
# 已创建: split_pdfs\066-间离Verfremdung.pdf
#
# 正在处理 '交往理性（Communicative Rationality）'
# 页码范围: 243 到 247
# 已添加页面 247
# 已创建: split_pdfs\067-交往理性Communicative Rationality.pdf
#
# 正在处理 '阶级（Class）'
# 页码范围: 248 到 250
# 已添加页面 250
# 已创建: split_pdfs\068-阶级Class.pdf
#
# 正在处理 '姐妹情谊（Sisterhood）'
# 页码范围: 251 到 254
# 已添加页面 254
# 已创建: split_pdfs\069-姐妹情谊Sisterhood.pdf
#
# 正在处理 '解构（Deconstruction）'
# 页码范围: 255 到 259
# 已添加页面 259
# 已创建: split_pdfs\070-解构Deconstruction.pdf
#
# 正在处理 '解构的伦理学（the Ethics of Deconstruction）'
# 页码范围: 260 到 263
# 已添加页面 263
# 已创建: split_pdfs\071-解构的伦理学the Ethics of Deconstruction.pdf
#
# 正在处理 '解释学（Hermeneutics）'
# 页码范围: 264 到 266
# 已添加页面 266
# 已创建: split_pdfs\072-解释学Hermeneutics.pdf
#
# 正在处理 '解辖域化（Deterritorialisation）'
# 页码范围: 267 到 269
# 已添加页面 269
# 已创建: split_pdfs\073-解辖域化Deterritorialisation.pdf
#
# 正在处理 '景观社会（the Society of the Spectacle）'
# 页码范围: 270 到 272
# 已添加页面 272
# 已创建: split_pdfs\074-景观社会the Society of the Spectacle.pdf
#
# 正在处理 '镜像阶段（the Mirror Stage）'
# 页码范围: 273 到 276
# 已添加页面 276
# 已创建: split_pdfs\075-镜像阶段the Mirror Stage.pdf
#
# 正在处理 '救赎（Redemption）'
# 页码范围: 277 到 280
# 已添加页面 280
# 已创建: split_pdfs\076-救赎Redemption.pdf
#
# 正在处理 '绝境（Aporias）'
# 页码范围: 281 到 287
# 已添加页面 287
# 已创建: split_pdfs\077-绝境Aporias.pdf
#
# 正在处理 'K'
# 页码范围: 288 到 287
#
# 已创建: split_pdfs\078-K.pdf
#
# 正在处理 '客体导向本体论（Ontology of object orientation）'
# 页码范围: 288 到 292
# 已添加页面 292
# 已创建: split_pdfs\079-客体导向本体论Ontology of object orientation.pdf
#
# 正在处理 '空间（Space）'
# 页码范围: 293 到 297
# 已添加页面 297
# 已创建: split_pdfs\080-空间Space.pdf
#
# 正在处理 '空间生产（Production of Space）'
# 页码范围: 298 到 300
# 已添加页面 300
# 已创建: split_pdfs\081-空间生产Production of Space.pdf
#
# 正在处理 '空间正义（Spatial Justice）'
# 页码范围: 301 到 304
# 已添加页面 304
# 已创建: split_pdfs\082-空间正义Spatial Justice.pdf
#
# 正在处理 '块茎（Rhizome）'
# 页码范围: 305 到 309
# 已添加页面 309
# 已创建: split_pdfs\083-块茎Rhizome.pdf
#
# 正在处理 '快感（Pleasure）'
# 页码范围: 310 到 312
# 已添加页面 312
# 已创建: split_pdfs\084-快感Pleasure.pdf
#
# 正在处理 '狂欢（Carnival）'
# 页码范围: 313 到 316
# 已添加页面 316
# 已创建: split_pdfs\085-狂欢Carnival.pdf
#
# 正在处理 'L'
# 页码范围: 317 到 316
#
# 已创建: split_pdfs\086-L.pdf
#
# 正在处理 '浪荡子（Flaneur）'
# 页码范围: 317 到 320
# 已添加页面 320
# 已创建: split_pdfs\087-浪荡子Flaneur.pdf
#
# 正在处理 '礼物（Gift）'
# 页码范围: 321 到 323
# 已添加页面 323
# 已创建: split_pdfs\088-礼物Gift.pdf
#
# 正在处理 '理论（Theory）'
# 页码范围: 324 到 327
# 已添加页面 327
# 已创建: split_pdfs\089-理论Theory.pdf
#
# 正在处理 '理性（Reason, Vernunft）'
# 页码范围: 328 到 331
# 已添加页面 331
# 已创建: split_pdfs\090-理性Reason Vernunft.pdf
#
# 正在处理 '零度写作（Writing Degree Zero）'
# 页码范围: 332 到 335
# 已添加页面 335
# 已创建: split_pdfs\091-零度写作Writing Degree Zero.pdf
#
# 正在处理 '逻各斯中心主义（Logocentrism）'
# 页码范围: 336 到 340
# 已添加页面 340
# 已创建: split_pdfs\092-逻各斯中心主义Logocentrism.pdf
#
# 正在处理 'M'
# 页码范围: 341 到 340
#
# 已创建: split_pdfs\093-M.pdf
#
# 正在处理 '绵延（Duration）'
# 页码范围: 341 到 344
# 已添加页面 344
# 已创建: split_pdfs\094-绵延Duration.pdf
#
# 正在处理 '免疫（Immune）'
# 页码范围: 345 到 348
# 已添加页面 348
# 已创建: split_pdfs\095-免疫Immune.pdf
#
# 正在处理 '民族—国家（Nation-State）'
# 页码范围: 349 到 351
# 已添加页面 351
# 已创建: split_pdfs\096-民族国家Nation-State.pdf
#
# 正在处理 '民族志（Ethnography）'
# 页码范围: 352 到 355
# 已添加页面 355
# 已创建: split_pdfs\097-民族志Ethnography.pdf
#
# 正在处理 '模拟（Mimicry）'
# 页码范围: 356 到 358
# 已添加页面 358
# 已创建: split_pdfs\098-模拟Mimicry.pdf
#
# 正在处理 '陌生化（Oстранение）'
# 页码范围: 359 到 362
# 已添加页面 362
# 已创建: split_pdfs\099-陌生化Oстранение.pdf
#
# 正在处理 'N'
# 页码范围: 363 到 362
#
# 已创建: split_pdfs\100-N.pdf
#
# 正在处理 '内爆（Implosion）'
# 页码范围: 363 到 366
# 已添加页面 366
# 已创建: split_pdfs\101-内爆Implosion.pdf
#
# 正在处理 '内在/超越（Immanent/Transcendent）'
# 页码范围: 367 到 371
# 已添加页面 371
# 已创建: split_pdfs\102-内在超越ImmanentTranscendent.pdf
#
# 正在处理 '男性中心主义（Androcentrism）'
# 页码范围: 372 到 375
# 已添加页面 375
# 已创建: split_pdfs\103-男性中心主义Androcentrism.pdf
#
# 正在处理 '能指（Singifier）'
# 页码范围: 376 到 379
# 已添加页面 379
# 已创建: split_pdfs\104-能指Singifier.pdf
#
# 正在处理 '拟像（Simulation）'
# 页码范围: 380 到 382
# 已添加页面 382
# 已创建: split_pdfs\105-拟像Simulation.pdf
#
# 正在处理 '女性奥秘论（Feminine Mystique）'
# 页码范围: 383 到 386
# 已添加页面 386
# 已创建: split_pdfs\106-女性奥秘论Feminine Mystique.pdf
#
# 正在处理 '女性气质（Femininity）'
# 页码范围: 387 到 390
# 已添加页面 390
# 已创建: split_pdfs\107-女性气质Femininity.pdf
#
# 正在处理 '女性主义（Feminism）'
# 页码范围: 391 到 394
# 已添加页面 394
# 已创建: split_pdfs\108-女性主义Feminism.pdf
#
# 正在处理 'P'
# 页码范围: 395 到 394
#
# 已创建: split_pdfs\109-P.pdf
#
# 正在处理 '批判理论（Critical Theory）'
# 页码范围: 395 到 399
# 已添加页面 399
# 已创建: split_pdfs\110-批判理论Critical Theory.pdf
#
# 正在处理 '普遍性/普遍主义（Universality/Universalism）'
# 页码范围: 400 到 402
# 已添加页面 402
# 已创建: split_pdfs\111-普遍性普遍主义UniversalityUniversalism.pdf
#
# 正在处理 '谱系学（Genealogy）'
# 页码范围: 403 到 406
# 已添加页面 406
# 已创建: split_pdfs\112-谱系学Genealogy.pdf
#
# 正在处理 'Q'
# 页码范围: 407 到 406
#
# 已创建: split_pdfs\113-Q.pdf
#
# 正在处理 '歧义/歧见（mésentente）'
# 页码范围: 407 到 410
# 已添加页面 410
# 已创建: split_pdfs\114-歧义歧见mésentente.pdf
#
# 正在处理 '奇异性（singularity）'
# 页码范围: 411 到 414
# 已添加页面 414
# 已创建: split_pdfs\115-奇异性singularity.pdf
#
# 正在处理 '启蒙（Enlightenment）'
# 页码范围: 415 到 419
# 已添加页面 419
# 已创建: split_pdfs\116-启蒙Enlightenment.pdf
#
# 正在处理 '启蒙辩证法（Dialectic of Enlightenment）'
# 页码范围: 420 到 423
# 已添加页面 423
# 已创建: split_pdfs\117-启蒙辩证法Dialectic of Enlightenment.pdf
#
# 正在处理 '千高原（A Thousand Plateaus）'
# 页码范围: 424 到 427
# 已添加页面 427
# 已创建: split_pdfs\118-千高原A Thousand Plateaus.pdf
#
# 正在处理 '潜能（Potentiality）'
# 页码范围: 428 到 430
# 已添加页面 430
# 已创建: split_pdfs\119-潜能Potentiality.pdf
#
# 正在处理 '潜在（Virtual）'
# 页码范围: 431 到 435
# 已添加页面 435
# 已创建: split_pdfs\120-潜在Virtual.pdf
#
# 正在处理 '强度（Intensity）'
# 页码范围: 436 到 439
# 已添加页面 439
# 已创建: split_pdfs\121-强度Intensity.pdf
#
# 正在处理 '情动/情感（affect）'
# 页码范围: 440 到 444
# 已添加页面 444
# 已创建: split_pdfs\122-情动情感affect.pdf
#
# 正在处理 '情感结构（Structures of Feeling）'
# 页码范围: 445 到 447
# 已添加页面 447
# 已创建: split_pdfs\123-情感结构Structures of Feeling.pdf
#
# 正在处理 '全景敞视主义（Panopticism）'
# 页码范围: 448 到 451
# 已添加页面 451
# 已创建: split_pdfs\124-全景敞视主义Panopticism.pdf
#
# 正在处理 '权力（Power）'
# 页码范围: 452 到 454
# 已添加页面 454
# 已创建: split_pdfs\125-权力Power.pdf
#
# 正在处理 '权力意志（Will to Power）'
# 页码范围: 455 到 458
# 已添加页面 458
# 已创建: split_pdfs\126-权力意志Will to Power.pdf
#
# 正在处理 '权力—知识（Power-Knowledge）'
# 页码范围: 459 到 463
# 已添加页面 463
# 已创建: split_pdfs\127-权力知识Power-Knowledge.pdf
#
# 正在处理 'R'
# 页码范围: 464 到 463
#
# 已创建: split_pdfs\128-R.pdf
#
# 正在处理 '人类纪（Anthropocene）'
# 页码范围: 464 到 467
# 已添加页面 467
# 已创建: split_pdfs\129-人类纪Anthropocene.pdf
#
# 正在处理 '人文主义（Humanism）'
# 页码范围: 468 到 471
# 已添加页面 471
# 已创建: split_pdfs\130-人文主义Humanism.pdf
#
# 正在处理 '人之死（Death of Men）'
# 页码范围: 472 到 475
# 已添加页面 475
# 已创建: split_pdfs\131-人之死Death of Men.pdf
#
# 正在处理 '认识论断裂（Epistemological Rupture）'
# 页码范围: 476 到 478
# 已添加页面 478
# 已创建: split_pdfs\132-认识论断裂Epistemological Rupture.pdf
#
# 正在处理 '认知暴力（Epistemic Violence）'
# 页码范围: 479 到 482
# 已添加页面 482
# 已创建: split_pdfs\133-认知暴力Epistemic Violence.pdf
#
# 正在处理 '认知图绘（Cognitive Mapping）'
# 页码范围: 483 到 485
# 已添加页面 485
# 已创建: split_pdfs\134-认知图绘Cognitive Mapping.pdf
#
# 正在处理 '日常生活（Everyday Life）'
# 页码范围: 486 到 490
# 已添加页面 490
# 已创建: split_pdfs\135-日常生活Everyday Life.pdf
#
# 正在处理 'S'
# 页码范围: 491 到 490
#
# 已创建: split_pdfs\136-S.pdf
#
# 正在处理 '赛博格（cyborg）'
# 页码范围: 491 到 494
# 已添加页面 494
# 已创建: split_pdfs\137-赛博格cyborg.pdf
#
# 正在处理 '赛博空间（Cyberspace）'
# 页码范围: 495 到 497
# 已添加页面 497
# 已创建: split_pdfs\138-赛博空间Cyberspace.pdf
#
# 正在处理 '商品拜物教（Commodity Fetishism）'
# 页码范围: 498 到 503
# 已添加页面 503
# 已创建: split_pdfs\139-商品拜物教Commodity Fetishism.pdf
#
# 正在处理 '上帝之死（God's Death）'
# 页码范围: 504 到 507
# 已添加页面 507
# 已创建: split_pdfs\140-上帝之死Gods Death.pdf
#
# 正在处理 '社群（Community）'
# 页码范围: 508 到 510
# 已添加页面 510
# 已创建: split_pdfs\141-社群Community.pdf
#
# 正在处理 '身份/认同（Identity）'
# 页码范围: 511 到 514
# 已添加页面 514
# 已创建: split_pdfs\142-身份认同Identity.pdf
#
# 正在处理 '身体（body）'
# 页码范围: 515 到 518
# 已添加页面 518
# 已创建: split_pdfs\143-身体body.pdf
#
# 正在处理 '深描（Thick Description）'
# 页码范围: 519 到 521
# 已添加页面 521
# 已创建: split_pdfs\144-深描Thick Description.pdf
#
# 正在处理 '神话/神话学（Myth/Mythology）'
# 页码范围: 522 到 524
# 已添加页面 524
# 已创建: split_pdfs\145-神话神话学MythMythology.pdf
#
# 正在处理 '神话—原型（Mythic-Archetypal）'
# 页码范围: 525 到 528
# 已添加页面 528
# 已创建: split_pdfs\146-神话原型Mythic-Archetypal.pdf
#
# 正在处理 '神圣人（homo sacer）'
# 页码范围: 529 到 533
# 已添加页面 533
# 已创建: split_pdfs\147-神圣人homo sacer.pdf
#
# 正在处理 '审美（Aesthetic）'
# 页码范围: 534 到 536
# 已添加页面 536
# 已创建: split_pdfs\148-审美Aesthetic.pdf
#
# 正在处理 '生成（Becoming）'
# 页码范围: 537 到 541
# 已添加页面 541
# 已创建: split_pdfs\149-生成Becoming.pdf
#
# 正在处理 '生命权力/生命政治（Biopower/Biopolitics）'
# 页码范围: 542 到 545
# 已添加页面 545
# 已创建: split_pdfs\150-生命权力生命政治BiopowerBiopolitics.pdf
#
# 正在处理 '生态文学（Ecological Literature）'
# 页码范围: 546 到 550
# 已添加页面 550
# 已创建: split_pdfs\151-生态文学Ecological Literature.pdf
#
# 正在处理 '时间/时间-空间（Time/ Time-Space）'
# 页码范围: 551 到 554
# 已添加页面 554
# 已创建: split_pdfs\152-时间时间-空间Time Time-Space.pdf
#
# 正在处理 '时空压缩（Time-Space Compression）'
# 页码范围: 555 到 558
# 已添加页面 558
# 已创建: split_pdfs\153-时空压缩Time-Space Compression.pdf
#
# 正在处理 '事件（Event）'
# 页码范围: 559 到 562
# 已添加页面 562
# 已创建: split_pdfs\154-事件Event.pdf
#
# 正在处理 '世界体系（World-System）'
# 页码范围: 563 到 567
# 已添加页面 567
# 已创建: split_pdfs\155-世界体系World-System.pdf
#
# 正在处理 '世俗的启迪（Profane Illumination）'
# 页码范围: 568 到 571
# 已添加页面 571
# 已创建: split_pdfs\156-世俗的启迪Profane Illumination.pdf
#
# 正在处理 '市民社会（Civil Society）'
# 页码范围: 572 到 575
# 已添加页面 575
# 已创建: split_pdfs\157-市民社会Civil Society.pdf
#
# 正在处理 '属下/属下阶层（Subaltern）'
# 页码范围: 576 到 578
# 已添加页面 578
# 已创建: split_pdfs\158-属下属下阶层Subaltern.pdf
#
# 正在处理 '述行（Performative）'
# 页码范围: 579 到 581
# 已添加页面 581
# 已创建: split_pdfs\159-述行Performative.pdf
#
# 正在处理 '双性同体（Androgyny）'
# 页码范围: 582 到 585
# 已添加页面 585
# 已创建: split_pdfs\160-双性同体Androgyny.pdf
#
# 正在处理 '碎片（Fragments）'
# 页码范围: 586 到 589
# 已添加页面 589
# 已创建: split_pdfs\161-碎片Fragments.pdf
#
# 正在处理 '所指（Signified）'
# 页码范围: 590 到 592
# 已添加页面 592
# 已创建: split_pdfs\162-所指Signified.pdf
#
# 正在处理 'T'
# 页码范围: 593 到 592
#
# 已创建: split_pdfs\163-T.pdf
#
# 正在处理 '他人/他者（autre/Autre）'
# 页码范围: 593 到 595
# 已添加页面 595
# 已创建: split_pdfs\164-他人他者autreAutre.pdf
#
# 正在处理 '逃逸线（ligne de fuite）'
# 页码范围: 596 到 599
# 已添加页面 599
# 已创建: split_pdfs\165-逃逸线ligne de fuite.pdf
#
# 正在处理 '同质性/异质性（Homogeneity/Heterogeneity）'
# 页码范围: 600 到 603
# 已添加页面 603
# 已创建: split_pdfs\166-同质性异质性HomogeneityHeterogeneity.pdf
#
# 正在处理 'W'
# 页码范围: 604 到 603
#
# 已创建: split_pdfs\167-W.pdf
#
# 正在处理 '晚期资本主义（Late Capitalism）'
# 页码范围: 604 到 607
# 已添加页面 607
# 已创建: split_pdfs\168-晚期资本主义Late Capitalism.pdf
#
# 正在处理 '文本（Text）'
# 页码范围: 608 到 611
# 已添加页面 611
# 已创建: split_pdfs\169-文本Text.pdf
#
# 正在处理 '文化霸权（Hegemony）'
# 页码范围: 612 到 615
# 已添加页面 615
# 已创建: split_pdfs\170-文化霸权Hegemony.pdf
#
# 正在处理 '文化帝国主义（Cultural Imperialism）'
# 页码范围: 616 到 619
# 已添加页面 619
# 已创建: split_pdfs\171-文化帝国主义Cultural Imperialism.pdf
#
# 正在处理 '文化工业（Culture Industry）'
# 页码范围: 620 到 624
# 已添加页面 624
# 已创建: split_pdfs\172-文化工业Culture Industry.pdf
#
# 正在处理 '文化记忆（Das kulturelle Gedächtnis）'
# 页码范围: 625 到 628
# 已添加页面 628
# 已创建: split_pdfs\173-文化记忆Das kulturelle Gedächtnis.pdf
#
# 正在处理 '文化唯物主义（Cultural Materialism）'
# 页码范围: 629 到 633
# 已添加页面 633
# 已创建: split_pdfs\174-文化唯物主义Cultural Materialism.pdf
#
# 正在处理 '文化研究（Cultural Studies）'
# 页码范围: 634 到 637
# 已添加页面 637
# 已创建: split_pdfs\175-文化研究Cultural Studies.pdf
#
# 正在处理 '文化政治（Cultural Politics）'
# 页码范围: 638 到 642
# 已添加页面 642
# 已创建: split_pdfs\176-文化政治Cultural Politics.pdf
#
# 正在处理 '文化资本（Cultural Capital）'
# 页码范围: 643 到 646
# 已添加页面 646
# 已创建: split_pdfs\177-文化资本Cultural Capital.pdf
#
# 正在处理 '无器官身体（Body without Organs）'
# 页码范围: 647 到 651
# 已添加页面 651
# 已创建: split_pdfs\178-无器官身体Body without Organs.pdf
#
# 正在处理 '无意识（Inconscient）'
# 页码范围: 652 到 654
# 已添加页面 654
# 已创建: split_pdfs\179-无意识Inconscient.pdf
#
# 正在处理 '物化（Reification）'
# 页码范围: 655 到 658
# 已添加页面 658
# 已创建: split_pdfs\180-物化Reification.pdf
#
# 正在处理 '物质（Material）'
# 页码范围: 659 到 663
# 已添加页面 663
# 已创建: split_pdfs\181-物质Material.pdf
#
# 正在处理 'X'
# 页码范围: 664 到 663
#
# 已创建: split_pdfs\182-X.pdf
#
# 正在处理 '西方马克思主义（Western Marxism）'
# 页码范围: 664 到 667
# 已添加页面 667
# 已创建: split_pdfs\183-西方马克思主义Western Marxism.pdf
#
# 正在处理 '习性（Habitus）'
# 页码范围: 668 到 671
# 已添加页面 671
# 已创建: split_pdfs\184-习性Habitus.pdf
#
# 正在处理 '戏仿（Parody）'
# 页码范围: 672 到 676
# 已添加页面 676
# 已创建: split_pdfs\185-戏仿Parody.pdf
#
# 正在处理 '现代性（Modernity）'
# 页码范围: 677 到 680
# 已添加页面 680
# 已创建: split_pdfs\186-现代性Modernity.pdf
#
# 正在处理 '现代主义（Modernism）'
# 页码范围: 681 到 684
# 已添加页面 684
# 已创建: split_pdfs\187-现代主义Modernism.pdf
#
# 正在处理 '现象学（Phenomenology）'
# 页码范围: 685 到 688
# 已添加页面 688
# 已创建: split_pdfs\188-现象学Phenomenology.pdf
#
# 正在处理 '想象/象征/真实（the Imaginary/the Symbolic/the Real）'
# 页码范围: 689 到 693
# 已添加页面 693
# 已创建: split_pdfs\189-想象象征真实the Imaginarythe Symbolicthe Real.pdf
#
# 正在处理 '象征资本（Symbolic Capital）'
# 页码范围: 694 到 698
# 已添加页面 698
# 已创建: split_pdfs\190-象征资本Symbolic Capital.pdf
#
# 正在处理 '消费社会（Consumer Society）'
# 页码范围: 699 到 703
# 已添加页面 703
# 已创建: split_pdfs\191-消费社会Consumer Society.pdf
#
# 正在处理 '新教伦理（Protestant Ethic）'
# 页码范围: 704 到 706
# 已添加页面 706
# 已创建: split_pdfs\192-新教伦理Protestant Ethic.pdf
#
# 正在处理 '新历史主义（New Historicism, Neo-Historicism）'
# 页码范围: 707 到 709
# 已添加页面 709
# 已创建: split_pdfs\193-新历史主义New Historicism Neo-Historicism.pdf
#
# 正在处理 '新物质主义（New Materialism）'
# 页码范围: 710 到 713
# 已添加页面 713
# 已创建: split_pdfs\194-新物质主义New Materialism.pdf
#
# 正在处理 '星座（Constellation）'
# 页码范围: 714 到 717
# 已添加页面 717
# 已创建: split_pdfs\195-星座Constellation.pdf
#
# 正在处理 '行动力/能动性（Agency）'
# 页码范围: 718 到 721
# 已添加页面 721
# 已创建: split_pdfs\196-行动力能动性Agency.pdf
#
# 正在处理 '行动者网络理论（Actor-Network Theory）'
# 页码范围: 722 到 726
# 已添加页面 726
# 已创建: split_pdfs\197-行动者网络理论Actor-Network Theory.pdf
#
# 正在处理 '形而上学（Metaphysics）'
# 页码范围: 727 到 731
# 已添加页面 731
# 已创建: split_pdfs\198-形而上学Metaphysics.pdf
#
# 正在处理 '形式主义（Formalism）'
# 页码范围: 732 到 735
# 已添加页面 735
# 已创建: split_pdfs\199-形式主义Formalism.pdf
#
# 正在处理 '性别（Sex, Gender）'
# 页码范围: 736 到 739
# 已添加页面 739
# 已创建: split_pdfs\200-性别Sex Gender.pdf
#
# 正在处理 '性别表演（Gender Performance）'
# 页码范围: 740 到 743
# 已添加页面 743
# 已创建: split_pdfs\201-性别表演Gender Performance.pdf
#
# 正在处理 '性政治（Sexual Politics）'
# 页码范围: 744 到 747
# 已添加页面 747
# 已创建: split_pdfs\202-性政治Sexual Politics.pdf
#
# 正在处理 '叙事学（Narratology）'
# 页码范围: 748 到 751
# 已添加页面 751
# 已创建: split_pdfs\203-叙事学Narratology.pdf
#
# 正在处理 'Y'
# 页码范围: 752 到 751
#
# 已创建: split_pdfs\204-Y.pdf
#
# 正在处理 '延异（Différance）'
# 页码范围: 752 到 757
# 已添加页面 757
# 已创建: split_pdfs\205-延异Différance.pdf
#
# 正在处理 '言语行为理论（Speech Acts Theory）'
# 页码范围: 758 到 760
# 已添加页面 760
# 已创建: split_pdfs\206-言语行为理论Speech Acts Theory.pdf
#
# 正在处理 '厌女症（Misogyny）'
# 页码范围: 761 到 764
# 已添加页面 764
# 已创建: split_pdfs\207-厌女症Misogyny.pdf
#
# 正在处理 '移动性（Mobility）'
# 页码范围: 765 到 769
# 已添加页面 769
# 已创建: split_pdfs\208-移动性Mobility.pdf
#
# 正在处理 '仪式（Ritual）'
# 页码范围: 770 到 772
# 已添加页面 772
# 已创建: split_pdfs\209-仪式Ritual.pdf
#
# 正在处理 '异化（Alienation）'
# 页码范围: 773 到 775
# 已添加页面 775
# 已创建: split_pdfs\210-异化Alienation.pdf
#
# 正在处理 '异托邦（Heterotopia）'
# 页码范围: 776 到 780
# 已添加页面 780
# 已创建: split_pdfs\211-异托邦Heterotopia.pdf
#
# 正在处理 '意识形态（Ideology）'
# 页码范围: 781 到 786
# 已添加页面 786
# 已创建: split_pdfs\212-意识形态Ideology.pdf
#
# 正在处理 '意识形态国家机器（Ideological State Apparatuses）'
# 页码范围: 787 到 789
# 已添加页面 789
# 已创建: split_pdfs\213-意识形态国家机器Ideological State Apparatuses.pdf
#
# 正在处理 '隐喻/转喻（Metaphor/Metonymy）'
# 页码范围: 790 到 794
# 已添加页面 794
# 已创建: split_pdfs\214-隐喻转喻MetaphorMetonymy.pdf
#
# 正在处理 '永恒轮回（Eternal Return）'
# 页码范围: 795 到 798
# 已添加页面 798
# 已创建: split_pdfs\215-永恒轮回Eternal Return.pdf
#
# 正在处理 '忧郁（Melancholy）'
# 页码范围: 799 到 801
# 已添加页面 801
# 已创建: split_pdfs\216-忧郁Melancholy.pdf
#
# 正在处理 '游牧（Nomad）'
# 页码范围: 802 到 805
# 已添加页面 805
# 已创建: split_pdfs\217-游牧Nomad.pdf
#
# 正在处理 '有机知识分子（Organic Intellectuals）'
# 页码范围: 806 到 808
# 已添加页面 808
# 已创建: split_pdfs\218-有机知识分子Organic Intellectuals.pdf
#
# 正在处理 '语言转向（the Linguistic Turn）'
# 页码范围: 809 到 812
# 已添加页面 812
# 已创建: split_pdfs\219-语言转向the Linguistic Turn.pdf
#
# 正在处理 '语义学（Semantics）'
# 页码范围: 813 到 816
# 已添加页面 816
# 已创建: split_pdfs\220-语义学Semantics.pdf
#
# 正在处理 '欲望（Desire）'
# 页码范围: 817 到 821
# 已添加页面 821
# 已创建: split_pdfs\221-欲望Desire.pdf
#
# 正在处理 '欲望机器（Desiring-Machines）'
# 页码范围: 822 到 825
# 已添加页面 825
# 已创建: split_pdfs\222-欲望机器Desiring-Machines.pdf
#
# 正在处理 '寓言（Allegory）'
# 页码范围: 826 到 829
# 已添加页面 829
# 已创建: split_pdfs\223-寓言Allegory.pdf
#
# 正在处理 '元历史（Metahistory）'
# 页码范围: 830 到 833
# 已添加页面 833
# 已创建: split_pdfs\224-元历史Metahistory.pdf
#
# 正在处理 '元叙事（Metanarrative）'
# 页码范围: 834 到 836
# 已添加页面 836
# 已创建: split_pdfs\225-元叙事Metanarrative.pdf
#
# 正在处理 '怨恨（Ressentiment）'
# 页码范围: 837 到 840
# 已添加页面 840
# 已创建: split_pdfs\226-怨恨Ressentiment.pdf
#
# 正在处理 'Z'
# 页码范围: 841 到 840
#
# 已创建: split_pdfs\227-Z.pdf
#
# 正在处理 '在场/缺席（Presence/Absence）'
# 页码范围: 841 到 844
# 已添加页面 844
# 已创建: split_pdfs\228-在场缺席PresenceAbsence.pdf
#
# 正在处理 '褶子（Fold）'
# 页码范围: 845 到 849
# 已添加页面 849
# 已创建: split_pdfs\229-褶子Fold.pdf
#
# 正在处理 '阵地战（War of Position）'
# 页码范围: 850 到 852
# 已添加页面 852
# 已创建: split_pdfs\230-阵地战War of Position.pdf
#
# 正在处理 '震惊（Shock）'
# 页码范围: 853 到 855
# 已添加页面 855
# 已创建: split_pdfs\231-震惊Shock.pdf
#
# 正在处理 '政治无意识（Political Unconscious）'
# 页码范围: 856 到 858
# 已添加页面 858
# 已创建: split_pdfs\232-政治无意识Political Unconscious.pdf
#
# 正在处理 '症状阅读（Symptomatic Reading）'
# 页码范围: 859 到 862
# 已添加页面 862
# 已创建: split_pdfs\233-症状阅读Symptomatic Reading.pdf
#
# 正在处理 '知识考古学（the Archeology of Knowledge）'
# 页码范围: 863 到 866
# 已添加页面 866
# 已创建: split_pdfs\234-知识考古学the Archeology of Knowledge.pdf
#
# 正在处理 '知识型（épistèmé）'
# 页码范围: 867 到 870
# 已添加页面 870
# 已创建: split_pdfs\235-知识型épistèmé.pdf
#
# 正在处理 '治理术（gouvernementalité）'
# 页码范围: 871 到 874
# 已添加页面 874
# 已创建: split_pdfs\236-治理术gouvernementalité.pdf
#
# 正在处理 '诸众（Multitude）'
# 页码范围: 875 到 879
# 已添加页面 879
# 已创建: split_pdfs\237-诸众Multitude.pdf
#
# 正在处理 '主奴辩证法（the Dialectic of the Master and the Slave）'
# 页码范围: 880 到 884
# 已添加页面 884
# 已创建: split_pdfs\238-主奴辩证法the Dialectic of the Master and the Slave.pdf
#
# 正在处理 '主权（Sovereignty）'
# 页码范围: 885 到 887
# 已添加页面 887
# 已创建: split_pdfs\239-主权Sovereignty.pdf
#
# 正在处理 '主体/客体（Subject/Object）'
# 页码范围: 888 到 892
# 已添加页面 892
# 已创建: split_pdfs\240-主体客体SubjectObject.pdf
#
# 正在处理 '装配/装置（agencement/dispositif）'
# 页码范围: 893 到 897
# 已添加页面 897
# 已创建: split_pdfs\241-装配装置agencementdispositif.pdf
#
# 正在处理 '资本/资本主义（Capital/Capitalism）'
# 页码范围: 898 到 900
# 已添加页面 900
# 已创建: split_pdfs\242-资本资本主义CapitalCapitalism.pdf
#
# 正在处理 '自然之镜（Mirror of Nature）'
# 页码范围: 901 到 903
# 已添加页面 903
# 已创建: split_pdfs\243-自然之镜Mirror of Nature.pdf
#
# 正在处理 '自我技术（Technologies of the Self）'
# 页码范围: 904 到 907
# 已添加页面 907
# 已创建: split_pdfs\244-自我技术Technologies of the Self.pdf
#
# 正在处理 '自由（Freedom）'
# 页码范围: 908 到 912
# 已添加页面 912
# 已创建: split_pdfs\245-自由Freedom.pdf
#
# 正在处理 '自由主义（Liberalism）'
# 页码范围: 913 到 917
# 已添加页面 917
# 已创建: split_pdfs\246-自由主义Liberalism.pdf
#
# 正在处理 '踪迹（Trace）'
# 页码范围: 918 到 922
# 已添加页面 922
# 已创建: split_pdfs\247-踪迹Trace.pdf
#
# 正在处理 '总体性（Totality）'
# 页码范围: 923 到 926
# 已添加页面 926
# 已创建: split_pdfs\248-总体性Totality.pdf
#
# 正在处理 '族裔（Ethnicity）'
# 页码范围: 927 到 929
# 已添加页面 929
# 已创建: split_pdfs\249-族裔Ethnicity.pdf
#
# 正在处理 '作者之死（the Death of the Author）'
# 页码范围: 930 到 933
# 已添加页面 933
# 已创建: split_pdfs\250-作者之死the Death of the Author.pdf
#
# 正在处理 '术语对照表'
# 页码范围: 934 到 945
# 已添加页面 945
# 已创建: split_pdfs\251-术语对照表.pdf

# %% [markdown]
# # epub

# %%
from ebooklib import epub
import html2text

def extract_epub_chapters(epub_path):
    """
    从epub文件中提取章节内容
    参数:
        epub_path: epub文件的路径
    返回:
        chapters: 包含章节标题和内容的字典列表
    """
    # 读取epub文件
    book = epub.read_epub(epub_path)
    
    # 创建HTML到文本的转换器
    h = html2text.HTML2Text()
    h.ignore_links = True
    h.ignore_images = True
    
    chapters = []
    
    # 遍历所有文档
    for item in book.get_items():
        # 检查是否为文档类型（使用正确的常量）
        if isinstance(item, epub.EpubHtml):
            # 获取文档内容
            content = item.get_content().decode('utf-8')
            # 将HTML转换为纯文本
            text = h.handle(content)
            
            # 获取章节标题
            title = item.title if hasattr(item, 'title') else None
            
            chapters.append({
                'title': title or f"Chapter {len(chapters) + 1}",
                'content': text
            })
    
    return chapters

def save_chapters_to_files(chapters, output_dir):
    """
    将提取的章节保存为单独的文本文件
    参数:
        chapters: 章节列表
        output_dir: 输出目录路径
    """
    import os
    os.makedirs(output_dir, exist_ok=True)
    
    for i, chapter in enumerate(chapters):
        # 清理文件名，移除不合法字符
        if chapter['title']:
            filename = "".join(x for x in chapter['title'] if x.isalnum() or x in (' ', '-', '_'))
            filename = f"{filename}.txt"
        else:
            filename = f"chapter_{i+1}.txt"
        
        filepath = os.path.join(output_dir, filename)
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(chapter['content'])
        print(f"已保存: {filepath}")

# 使用示例
if __name__ == "__main__":
    epub_path = "文化研究关键词 (汪民安) (Z-Library).epub"  # 替换为你的epub文件路径
    output_dir = "chapters"       # 输出目录
    
    chapters = extract_epub_chapters(epub_path)
    save_chapters_to_files(chapters, output_dir)
# Out:
# 已保存: chapters\Chapter 1.txt
# 已保存: chapters\Chapter 2.txt
# 已保存: chapters\Chapter 3.txt
# 已保存: chapters\Chapter 4.txt
# 已保存: chapters\Chapter 5.txt
# 已保存: chapters\Chapter 6.txt
# 已保存: chapters\Chapter 7.txt
# 已保存: chapters\Chapter 8.txt
# 已保存: chapters\Chapter 9.txt
# 已保存: chapters\Chapter 10.txt
# 已保存: chapters\Chapter 11.txt
# 已保存: chapters\Chapter 12.txt
# 已保存: chapters\Chapter 13.txt
# 已保存: chapters\Chapter 14.txt
# 已保存: chapters\Chapter 15.txt
# 已保存: chapters\Chapter 16.txt
# 已保存: chapters\Chapter 17.txt
# 已保存: chapters\Chapter 18.txt
# 已保存: chapters\Chapter 19.txt
# 已保存: chapters\Chapter 174.txt
# 已保存: chapters\Chapter 175.txt
# 已保存: chapters\Chapter 176.txt
# 已保存: chapters\Chapter 177.txt
# 已保存: chapters\Chapter 178.txt
# 已保存: chapters\Chapter 179.txt
# 已保存: chapters\Chapter 180.txt
# 已保存: chapters\Chapter 181.txt
# 已保存: chapters\Chapter 182.txt
# 已保存: chapters\Chapter 183.txt
# 已保存: chapters\Chapter 184.txt
# 已保存: chapters\Chapter 185.txt
# 已保存: chapters\Chapter 186.txt
# 已保存: chapters\Chapter 187.txt
# 已保存: chapters\Chapter 188.txt
# 已保存: chapters\Chapter 189.txt
# 已保存: chapters\Chapter 190.txt
# 已保存: chapters\Chapter 191.txt
# 已保存: chapters\Chapter 192.txt
# 已保存: chapters\Chapter 193.txt
# 已保存: chapters\Chapter 194.txt
# 已保存: chapters\Chapter 195.txt
# 已保存: chapters\Chapter 196.txt
# 已保存: chapters\Chapter 197.txt
# 已保存: chapters\Chapter 198.txt
# 已保存: chapters\Chapter 199.txt
# 已保存: chapters\Chapter 200.txt
# 已保存: chapters\Chapter 201.txt
# 已保存: chapters\Chapter 202.txt
# 已保存: chapters\Chapter 203.txt
# 已保存: chapters\Chapter 204.txt
# 已保存: chapters\Chapter 205.txt
# 已保存: chapters\Chapter 206.txt
# 已保存: chapters\Chapter 207.txt
# 已保存: chapters\Chapter 208.txt
# 已保存: chapters\Chapter 209.txt
# 已保存: chapters\Chapter 210.txt
# 已保存: chapters\Chapter 211.txt
# 已保存: chapters\Chapter 212.txt
# 已保存: chapters\Chapter 213.txt
# 已保存: chapters\Chapter 214.txt
# 已保存: chapters\Chapter 215.txt
# 已保存: chapters\Chapter 216.txt
# 已保存: chapters\Chapter 217.txt
# 已保存: chapters\Chapter 218.txt
# 已保存: chapters\Chapter 219.txt
# 已保存: chapters\Chapter 220.txt
# 已保存: chapters\Chapter 221.txt
# 已保存: chapters\Chapter 222.txt
# 已保存: chapters\Chapter 223.txt
# 已保存: chapters\Chapter 224.txt
# 已保存: chapters\Chapter 225.txt
# 已保存: chapters\Chapter 226.txt
# 已保存: chapters\Chapter 227.txt
# 已保存: chapters\Chapter 228.txt
# 已保存: chapters\Chapter 229.txt
# 已保存: chapters\Chapter 230.txt
# 已保存: chapters\Chapter 231.txt
# 已保存: chapters\Chapter 232.txt

# %%
import json
import re
import os

def process_chapter_content(text):
    """
    处理单个章节内容，提取二级标题和段落
    返回: 字典，键为二级标题，值为段落列表
    """
    # 寻找二级标题（以##开头）
    title_match = re.search(r'^##\s+(.+)$', text, re.MULTILINE)
    if not title_match:
        return {}
    
    title = title_match.group(1).strip()
    
    # 获取标题后的内容
    content = text[title_match.end():].strip()
    
    # 用连续换行符分割段落
    paragraphs = [p.strip() for p in re.split(r'\n\s*\n', content)]
    
    # 过滤掉长度小于10的段落
    valid_paragraphs = [p.replace('\n','') for p in paragraphs if len(p) >= 10]
    
    return {title: valid_paragraphs}

def process_all_chapters(directory):
    """
    处理目录中的所有txt文件
    参数:
        directory: chapters目录的路径
    返回:
        包含所有章节内容的字典
    """
    result = {}
    
    # 遍历目录中的所有txt文件
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_path = os.path.join(directory, filename)
            try:
                # 读取文件内容
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                # 处理章节内容
                chapter_dict = process_chapter_content(content)
                # 更新结果字典
                result.update(chapter_dict)
                
            except Exception as e:
                print(f"处理文件 {filename} 时出错: {str(e)}")
    
    return result

def save_to_json(data, output_file):
    """
    将数据保存为JSON文件
    """
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# 使用示例
if __name__ == "__main__":
    chapters_dir = "chapters"  # 指定chapters目录的路径
    output_file = "chapters_content.json"  # 输出JSON文件的路径
    
    # 处理所有章节
    result = process_all_chapters(chapters_dir)
    print(len(result))
    # 保存为JSON文件
    save_to_json(result, output_file)
    
    print(f"处理完成，结果已保存到 {output_file}")
# Out:
# 226
# 处理完成，结果已保存到 chapters_content.json

# %% [markdown]
# # 总结

# %%
import json
import logging
import time
import os
from typing import List, Dict, Optional, Union
from zhipuai import ZhipuAI


def setup_logging():
    """
    配置双重日志系统：控制台输出和错误文件记录
    """
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)

    # 创建logs目录
    os.makedirs('logs', exist_ok=True)

    # 控制台处理器
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console_handler.setFormatter(console_formatter)

    # 错误日志文件处理器
    error_handler = logging.FileHandler('logs/error.log', encoding='utf-8')
    error_handler.setLevel(logging.ERROR)
    error_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s\n详细信息：%(exc_info)s')
    error_handler.setFormatter(error_formatter)

    logger.addHandler(console_handler)
    logger.addHandler(error_handler)


class TextSummarizer:
    """
    文本总结器，负责生成总结并保存相关文件
    """

    def __init__(self, api_key: str, model: str = "glm-4"):
        """
        初始化总结器

        Args:
            api_key: 智谱AI的API密钥
            model: 使用的模型名称
        """
        self.client = ZhipuAI(api_key=api_key)
        self.model = model
        self.summaries_dir = "summaries"
        os.makedirs(self.summaries_dir, exist_ok=True)
        logging.info(f"初始化TextSummarizer完成，使用模型: {model}")

    def create_summary(self, text: str, key: str, max_retries: int = 3) -> Optional[str]:
        """
        使用智谱AI为文本生成总结

        Args:
            text: 需要总结的文本内容
            key: 关键词/主题
            max_retries: 最大重试次数
        """
        retry_count = 0
        while retry_count < max_retries:
            try:
                prompt = f"请针对以下与'{key}'相关的回答，猜想该回答的对应问题是什么？"
                text = text.replace(' ','').replace('\n','')
                response = self.client.chat.completions.create(
                    model=self.model,
                    messages=[
                        {
                            "role": "system",
                            "content": "你是一位平易近人的文化研究教授，请猜想下面的回答对应最重要问题是什么？用简短的语言，只返回问题内容。"
                        },
                        {
                            "role": "user",
                            "content": f"{prompt}\n\n{text}"
                        }
                    ],
                    temperature=0.7,
                    top_p=0.7,
                    max_tokens=1024,
                    stream=False
                )

                if hasattr(response, 'choices') and len(response.choices) > 0:
                    summary = response.choices[0].message.content
                    logging.info(f"成功生成总结: {summary}")
                    return summary.strip()

            except Exception as e:
                retry_count += 1
                logging.error(f"生成总结时发生错误: {str(e)}", exc_info=True)
                if retry_count < max_retries:
                    time.sleep(2 * retry_count)
                continue

        return None

    def save_summary_and_text(self, summary: str, text: str, key: str, index: int) -> str:
        """
        将总结和原文保存到txt文件

        Args:
            summary: 生成的总结
            text: 原始文本
            key: 关键词/主题
            index: 文本块索引
        """
        safe_key = "".join(c for c in key if c.isalnum() or c in (' ', '-', '_')).strip()
        filename = f"{safe_key}_chunk_{index}.txt"
        filepath = os.path.join(self.summaries_dir, filename)

        try:
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(f"总结：\n{summary}\n\n原文：\n{text}")
            logging.info(f"已保存文件: {filepath}")
            return filepath
        except Exception as e:
            logging.error(f"保存文件时发生错误: {str(e)}", exc_info=True)
            return ""


class AlpacaFormatter:
    """
    负责将处理结果转换为Alpaca格式
    """

    @staticmethod
    def convert_to_alpaca(data: Dict[str, Dict]) -> List[Dict]:
        """
        将数据转换为Alpaca训练格式

        Args:
            data: 原始数据字典
        """
        alpaca_data = []

        for key, content in data.items():
            if "processed_chunks" in content:
                for item in content["processed_chunks"]:
                    alpaca_entry = {
                        "instruction": item["summary"],
                        "input": "",
                        "output": item["original"],
                        "metadata": {
                            "key": key,
                            "file_path": item.get("file_path", ""),
                            "length": item.get("length", 0)
                        }
                    }
                    alpaca_data.append(alpaca_entry)

        return alpaca_data

def process_content(input_file: str, output_file: str, summarizer: TextSummarizer):
    """
    主处理函数，读取JSON文件并生成总结
    
    Args:
        input_file: 输入JSON文件路径
        output_file: 输出JSON文件路径
        summarizer: TextSummarizer实例
    """
    try:
        # 读取输入文件
        with open(input_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        processed_data = {}
        
        # 处理每个关键词的内容
        for key, chunks in data.items():
            logging.info(f"正在处理关键词: {key}")
            results = []
            
            # 直接遍历列表中的文本块
            for i, chunk in enumerate(chunks, 1):
                logging.info(f"正在处理 {key} 的第 {i}/{len(chunks)} 个文本块")
                
                # 生成总结
                summary = summarizer.create_summary(chunk, key)
                if summary:
                    # 保存到文件
                    file_path = summarizer.save_summary_and_text(summary, chunk, key, i)
                    
                    results.append({
                        "summary": summary,
                        "length": len(chunk),
                        "file_path": file_path
                    })
                
                time.sleep(1)  # 避免API限制
            
            # 保存处理结果
            processed_data[key] = {
                "original": chunks,  # 保存原始列表
                "processed_chunks": results,
                "metadata": {
                    "chunk_count": len(results),
                    "total_length": sum(len(chunk) for chunk in chunks)
                }
            }
            
            # 保存中间结果
            with open(f"{output_file}.temp", 'w', encoding='utf-8') as f:
                json.dump(processed_data, f, ensure_ascii=False, indent=2)
        
        # 转换为Alpaca格式
        alpaca_data = AlpacaFormatter.convert_to_alpaca(processed_data)
        
        # 保存最终结果
        alpaca_output = output_file.replace('.json', '_alpaca.json')
        with open(alpaca_output, 'w', encoding='utf-8') as f:
            json.dump(alpaca_data, f, ensure_ascii=False, indent=2)
        
        logging.info(f"处理完成，结果已保存至: {alpaca_output}")
    
    except Exception as e:
        logging.error(f"处理文件时发生错误: {str(e)}", exc_info=True)
        raise
    
def main():
    """
    主函数，配置并启动处理流程
    """
    # 设置日志系统
    setup_logging()

    # 配置参数
    API_KEY = "9d1abe1ba97fe0d44c1d62ab171ab6b1.48MgiTMFTb7GKo9U"
    MODEL = "glm-4-flash"
    INPUT_FILE = "chapters_content.json"
    OUTPUT_FILE = "output.json"

    try:
        summarizer = TextSummarizer(API_KEY, MODEL)
        process_content(INPUT_FILE, OUTPUT_FILE, summarizer)

    except Exception as e:
        logging.error(f"程序执行出错: {str(e)}", exc_info=True)
        raise


if __name__ == "__main__":
    main()
# Out:
# 2024-12-16 15:18:54,940 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:18:54,940 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:18:54,940 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:18:54,977 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:18:54,977 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:18:54,977 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:18:54,980 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:18:54,980 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:18:54,980 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:18:55,842 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:18:55,842 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:18:55,842 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:18:55,849 - INFO - 成功生成总结: 什么是“擦抹”概念及其在解构主义中的作用？
# 2024-12-16 15:18:55,849 - INFO - 成功生成总结: 什么是“擦抹”概念及其在解构主义中的作用？
# 2024-12-16 15:18:55,849 - INFO - 成功生成总结: 什么是“擦抹”概念及其在解构主义中的作用？
# 2024-12-16 15:18:55,853 - INFO - 已保存文件: summaries\擦抹Under Erasure_chunk_1.txt
# 2024-12-16 15:18:55,853 - INFO - 已保存文件: summaries\擦抹Under Erasure_chunk_1.txt
# 2024-12-16 15:18:55,853 - INFO - 已保存文件: summaries\擦抹Under Erasure_chunk_1.txt
# 2024-12-16 15:18:56,859 - INFO - 正在处理 擦抹（Under Erasure） 的第 2/4 个文本块
# 2024-12-16 15:18:56,859 - INFO - 正在处理 擦抹（Under Erasure） 的第 2/4 个文本块
# 2024-12-16 15:18:56,859 - INFO - 正在处理 擦抹（Under Erasure） 的第 2/4 个文本块
# 2024-12-16 15:18:59,320 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:18:59,320 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 247
#     243         raise
#     246 if __name__ == "__main__":
# --> 247     main()
#
# Cell In[20], line 239, in main()
#     237 try:
#     238     summarizer = TextSummarizer(API_KEY, MODEL)
# --> 239     process_content(INPUT_FILE, OUTPUT_FILE, summarizer)
#     241 except Exception as e:
#     242     logging.error(f"程序执行出错: {str(e)}", exc_info=True)
#
# Cell In[20], line 194, in process_content(input_file, output_file, summarizer)
#     185         file_path = summarizer.save_summary_and_text(summary, chunk, key, i)
#     187         results.append({
#     188             "original": chunk,
#     189             "summary": summary,
#     190             "length": len(chunk),
#     191             "file_path": file_path
#     192         })
# --> 194     time.sleep(1)  # 避免API限制
#     196 # 保存处理结果
#     197 processed_data[key] = {
#     198     "original": chunks,  # 保存原始列表
#     199     "processed_chunks": results,
#    (...)
#     203     }
#     204 }
#
# KeyboardInterrupt:

# %%
import json
import logging
import time
import os
from typing import List, Dict, Optional, Union
from zhipuai import ZhipuAI


def setup_logging():
    """
    配置双重日志系统：控制台输出和错误文件记录
    """
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)

    # 创建logs目录
    os.makedirs('logs', exist_ok=True)

    # 控制台处理器
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console_handler.setFormatter(console_formatter)

    # 错误日志文件处理器
    error_handler = logging.FileHandler('logs/error.log', encoding='utf-8')
    error_handler.setLevel(logging.ERROR)
    error_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s\n详细信息：%(exc_info)s')
    error_handler.setFormatter(error_formatter)

    logger.addHandler(console_handler)
    logger.addHandler(error_handler)


class TextSummarizer:
    """
    文本总结器，负责生成总结并保存相关文件
    """

    def __init__(self, api_key: str, model: str = "glm-4"):
        """
        初始化总结器

        Args:
            api_key: 智谱AI的API密钥
            model: 使用的模型名称
        """
        self.client = ZhipuAI(api_key=api_key)
        self.model = model
        self.summaries_dir = "summaries"
        os.makedirs(self.summaries_dir, exist_ok=True)
        logging.info(f"初始化TextSummarizer完成，使用模型: {model}")

    def create_summary(self, text: str, key: str, max_retries: int = 3) -> Optional[str]:
        """
        使用智谱AI为文本生成总结

        Args:
            text: 需要总结的文本内容
            key: 关键词/主题
            max_retries: 最大重试次数
        """
        for retry_count in range(max_retries):
            try:
                response = self.client.chat.completions.create(
                    model=self.model,
                    messages=[{
                        "role": "system",
                        "content": "你是一位平易近人的文化研究教授，请猜想下面的回答对应最重要问题是什么？用简短的语言，只返回问题内容。"
                    }, {
                        "role": "user",
                        "content": f"请针对以下与'{key}'相关的回答，猜想该回答的对应问题是什么？\n\n{text}"
                    }],
                    temperature=0.7,
                    top_p=0.7,
                    max_tokens=1024,
                    stream=False
                )
                
                # 成功获取响应就直接返回
                if hasattr(response, 'choices') and response.choices:
                    summary = response.choices[0].message.content.strip()
                    logging.info(f"成功生成总结: {summary}")
                    return summary
                
                # 如果没有有效响应，记录错误但继续重试
                logging.error(f"API返回无效响应: {response}")
                
            except Exception as e:
                # 只在最后一次重试失败时记录错误
                if retry_count == max_retries - 1:
                    logging.error(f"生成总结失败，已重试{retry_count + 1}次: {str(e)}", exc_info=True)
                elif retry_count < max_retries - 1:
                    logging.warning(f"第{retry_count + 1}次尝试失败，准备重试: {str(e)}")
                    time.sleep(2 * (retry_count + 1))  # 递增等待时间
        
        return None

    def save_summary_and_text(self, summary: str, text: str, key: str, index: int) -> str:
        """
        将总结和原文保存到txt文件

        Args:
            summary: 生成的总结
            text: 原始文本
            key: 关键词/主题
            index: 文本块索引
        """
        safe_key = "".join(c for c in key if c.isalnum() or c in (' ', '-', '_')).strip()
        filename = f"{safe_key}_chunk_{index}.txt"
        filepath = os.path.join(self.summaries_dir, filename)

        try:
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(f"总结：\n{summary}\n\n原文：\n{text}")
            logging.info(f"已保存文件: {filepath}")
            return filepath
        except Exception as e:
            logging.error(f"保存文件时发生错误: {str(e)}", exc_info=True)
            return ""


class AlpacaFormatter:
    """
    负责将处理结果转换为Alpaca格式
    """

    @staticmethod
    def convert_to_alpaca(data: Dict[str, Dict]) -> List[Dict]:
        """
        将数据转换为Alpaca训练格式

        Args:
            data: 原始数据字典
        """
        alpaca_data = []

        for key, content in data.items():
            if "processed_chunks" in content:
                for item in content["processed_chunks"]:
                    alpaca_entry = {
                        "instruction": item["summary"],
                        "input": "",
                        "output": item["original"],
                        "metadata": {
                            "key": key,
                            "file_path": item.get("file_path", ""),
                            "length": item.get("length", 0)
                        }
                    }
                    alpaca_data.append(alpaca_entry)

        return alpaca_data


def process_content(input_file: str, output_file: str, summarizer: TextSummarizer):
    """
    主处理函数，读取JSON文件并生成总结
    
    Args:
        input_file: 输入JSON文件路径
        output_file: 输出JSON文件路径
        summarizer: TextSummarizer实例
    """
    try:
        # 读取输入文件
        with open(input_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        processed_data = {}
        
        # 处理每个关键词的内容
        for key, chunks in data.items():
            logging.info(f"正在处理关键词: {key}")
            results = []
            
            # 直接遍历列表中的文本块
            for i, chunk in enumerate(chunks, 1):
                logging.info(f"正在处理 {key} 的第 {i}/{len(chunks)} 个文本块")
                
                # 生成总结
                summary = summarizer.create_summary(chunk, key)
                if summary:
                    # 保存到文件
                    file_path = summarizer.save_summary_and_text(summary, chunk, key, i)
                    
                    results.append({
                        "original": chunk,
                        "summary": summary,
                        "length": len(chunk),
                        "file_path": file_path
                    })
                
                time.sleep(1)  # 避免API限制
            
            # 保存处理结果
            processed_data[key] = {
                "original": chunks,  # 保存原始列表
                "processed_chunks": results,
                "metadata": {
                    "chunk_count": len(results),
                    "total_length": sum(len(chunk) for chunk in chunks)
                }
            }
            
            # 保存中间结果
            with open(f"{output_file}.temp", 'w', encoding='utf-8') as f:
                json.dump(processed_data, f, ensure_ascii=False, indent=2)
        
        # 转换为Alpaca格式
        alpaca_data = AlpacaFormatter.convert_to_alpaca(processed_data)
        
        # 保存最终结果
        alpaca_output = output_file.replace('.json', '_alpaca.json')
        with open(alpaca_output, 'w', encoding='utf-8') as f:
            json.dump(alpaca_data, f, ensure_ascii=False, indent=2)
        
        logging.info(f"处理完成，结果已保存至: {alpaca_output}")
    
    except Exception as e:
        logging.error(f"处理文件时发生错误: {str(e)}", exc_info=True)
        raise


def main():
    """
    主函数，配置并启动处理流程
    """
    # 设置日志系统
    setup_logging()

    # 配置参数
    API_KEY = "9d1abe1ba97fe0d44c1d62ab171ab6b1.48MgiTMFTb7GKo9U"  # 替换为你的API密钥
    MODEL = "glm-4-flash"
    INPUT_FILE = "chapters_content.json"
    OUTPUT_FILE = "output.json"

    try:
        summarizer = TextSummarizer(API_KEY, MODEL)
        process_content(INPUT_FILE, OUTPUT_FILE, summarizer)

    except Exception as e:
        logging.error(f"程序执行出错: {str(e)}", exc_info=True)
        raise


if __name__ == "__main__":
    main()
# Out:
# 2024-12-16 15:25:26,134 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:25:26,134 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:25:26,134 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:25:26,134 - INFO - 初始化TextSummarizer完成，使用模型: glm-4-flash
# 2024-12-16 15:25:26,167 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:25:26,167 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:25:26,167 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:25:26,167 - INFO - 正在处理关键词: 擦抹（Under Erasure）
# 2024-12-16 15:25:26,173 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:25:26,173 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:25:26,173 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:25:26,173 - INFO - 正在处理 擦抹（Under Erasure） 的第 1/4 个文本块
# 2024-12-16 15:25:27,374 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:27,374 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:27,374 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:27,374 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:27,384 - INFO - 成功生成总结: 什么是“擦抹”（Under Erasure）的概念及其在解构主义中的作用？
# 2024-12-16 15:25:27,384 - INFO - 成功生成总结: 什么是“擦抹”（Under Erasure）的概念及其在解构主义中的作用？
# 2024-12-16 15:25:27,384 - INFO - 成功生成总结: 什么是“擦抹”（Under Erasure）的概念及其在解构主义中的作用？
TTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:34,649 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:34,649 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:34,649 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:34,655 - INFO - 成功生成总结: 普遍性/普遍主义是如何在哲学中体现的？
# 2024-12-16 15:25:34,655 - INFO - 成功生成总结: 普遍性/普遍主义是如何在哲学中体现的？
# 2024-12-16 15:25:34,655 - INFO - 成功生成总结: 普遍性/普遍主义是如何在哲学中体现的？
# 2024-12-16 15:25:34,655 - INFO - 成功生成总结: 普遍性/普遍主义是如何在哲学中体现的？
# 2024-12-16 15:25:34,660 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_1.txt
# 2024-12-16 15:25:34,660 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_1.txt
# 2024-12-16 15:25:34,660 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_1.txt
# 2024-12-16 15:25:34,660 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_1.txt
# 2024-12-16 15:25:35,671 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 2/10 个文本块
# 2024-12-16 15:25:35,671 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 2/10 个文本块
# 2024-12-16 15:25:35,671 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 2/10 个文本块
# 2024-12-16 15:25:35,671 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 2/10 个文本块
# 2024-12-16 15:25:36,509 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:36,509 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:36,509 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:36,509 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:36,521 - INFO - 成功生成总结: 普遍主义在黑尔和康德眼中的区别是什么？
# 2024-12-16 15:25:36,521 - INFO - 成功生成总结: 普遍主义在黑尔和康德眼中的区别是什么？
# 2024-12-16 15:25:36,521 - INFO - 成功生成总结: 普遍主义在黑尔和康德眼中的区别是什么？
# 2024-12-16 15:25:36,521 - INFO - 成功生成总结: 普遍主义在黑尔和康德眼中的区别是什么？
# 2024-12-16 15:25:36,525 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_2.txt
# 2024-12-16 15:25:36,525 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_2.txt
TTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:44,435 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:44,435 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:44,435 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:44,441 - INFO - 成功生成总结: 普遍性/普遍主义如何体现为道德判断的本质特征？
# 2024-12-16 15:25:44,441 - INFO - 成功生成总结: 普遍性/普遍主义如何体现为道德判断的本质特征？
# 2024-12-16 15:25:44,441 - INFO - 成功生成总结: 普遍性/普遍主义如何体现为道德判断的本质特征？
# 2024-12-16 15:25:44,441 - INFO - 成功生成总结: 普遍性/普遍主义如何体现为道德判断的本质特征？
# 2024-12-16 15:25:44,455 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_6.txt
# 2024-12-16 15:25:44,455 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_6.txt
# 2024-12-16 15:25:44,455 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_6.txt
# 2024-12-16 15:25:44,455 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_6.txt
# 2024-12-16 15:25:45,468 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 7/10 个文本块
# 2024-12-16 15:25:45,468 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 7/10 个文本块
# 2024-12-16 15:25:45,468 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 7/10 个文本块
# 2024-12-16 15:25:45,468 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 7/10 个文本块
# 2024-12-16 15:25:46,129 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:46,129 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:46,129 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:46,129 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:46,134 - INFO - 成功生成总结: 普遍主义的伦理学面向的对象是什么？
# 2024-12-16 15:25:46,134 - INFO - 成功生成总结: 普遍主义的伦理学面向的对象是什么？
# 2024-12-16 15:25:46,134 - INFO - 成功生成总结: 普遍主义的伦理学面向的对象是什么？
# 2024-12-16 15:25:46,134 - INFO - 成功生成总结: 普遍主义的伦理学面向的对象是什么？
# 2024-12-16 15:25:46,137 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_7.txt
# 2024-12-16 15:25:46,137 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_7.txt
# 2024-12-16 15:25:46,137 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_7.txt
# 2024-12-16 15:25:46,137 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_7.txt
# 2024-12-16 15:25:47,152 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 8/10 个文本块
# 2024-12-16 15:25:47,152 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 8/10 个文本块
# 2024-12-16 15:25:47,152 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 8/10 个文本块
# 2024-12-16 15:25:47,152 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 8/10 个文本块
# 2024-12-16 15:25:48,212 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:48,212 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:48,212 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:48,212 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:48,218 - INFO - 成功生成总结: 普遍主义在哪些领域应用最广泛？
# 2024-12-16 15:25:48,218 - INFO - 成功生成总结: 普遍主义在哪些领域应用最广泛？
# 2024-12-16 15:25:48,218 - INFO - 成功生成总结: 普遍主义在哪些领域应用最广泛？
# 2024-12-16 15:25:48,218 - INFO - 成功生成总结: 普遍主义在哪些领域应用最广泛？
# 2024-12-16 15:25:48,222 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_8.txt
# 2024-12-16 15:25:48,222 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_8.txt
# 2024-12-16 15:25:48,222 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_8.txt
# 2024-12-16 15:25:48,222 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_8.txt
# 2024-12-16 15:25:49,233 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 9/10 个文本块
# 2024-12-16 15:25:49,233 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 9/10 个文本块
# 2024-12-16 15:25:49,233 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 9/10 个文本块
# 2024-12-16 15:25:49,233 - INFO - 正在处理 普遍性/普遍主义（Universality/Universalism） 的第 9/10 个文本块
# 2024-12-16 15:25:49,737 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:49,737 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:49,737 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:49,737 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:25:49,744 - INFO - 成功生成总结: 普遍主义的界限是什么？
# 2024-12-16 15:25:49,744 - INFO - 成功生成总结: 普遍主义的界限是什么？
# 2024-12-16 15:25:49,744 - INFO - 成功生成总结: 普遍主义的界限是什么？
# 2024-12-16 15:25:49,744 - INFO - 成功生成总结: 普遍主义的界限是什么？
# 2024-12-16 15:25:49,749 - INFO - 已保存文件: summaries\普遍性普遍主义UniversalityUniversalism_chunk_9.txt
# 2024-12-16 15:26:11,424 - INFO - 已保存文件: summaries\谱系学Genealogy_chunk_8.txt
# 2024-12-16 15:26:12,440 - INFO - 正在处理关键词: 歧义/歧见（mésentente）
# 2024-12-16 15:26:12,440 - INFO - 正在处理关键词: 歧义/歧见（mésentente）
# 2024-12-16 15:26:12,440 - INFO - 正在处理关键词: 歧义/歧见（mésentente）
# 2024-12-16 15:26:12,440 - INFO - 正在处理关键词: 歧义/歧见（mésentente）
# 2024-12-16 15:26:12,444 - INFO - 正在处理 歧义/歧见（mésentente） 的第 1/6 个文本块
# 2024-12-16 15:26:12,444 - INFO - 正在处理 歧义/歧见（mésentente） 的第 1/6 个文本块
# 2024-12-16 15:26:12,444 - INFO - 正在处理 歧义/歧见（mésentente） 的第 1/6 个文本块
# 2024-12-16 15:26:12,444 - INFO - 正在处理 歧义/歧见（mésentente） 的第 1/6 个文本块
# 2024-12-16 15:26:15,207 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:15,207 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:15,207 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:15,207 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:15,215 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其在朗西埃平等主义政治思想中的意义？
# 2024-12-16 15:26:15,215 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其在朗西埃平等主义政治思想中的意义？
# 2024-12-16 15:26:15,215 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其在朗西埃平等主义政治思想中的意义？
# 2024-12-16 15:26:15,215 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其在朗西埃平等主义政治思想中的意义？
# 2024-12-16 15:26:15,219 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_1.txt
# 2024-12-16 15:26:15,219 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_1.txt
# 2024-12-16 15:26:15,219 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_1.txt
# 2024-12-16 15:26:15,219 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_1.txt
# 2024-12-16 15:26:16,230 - INFO - 正在处理 歧义/歧见（mésentente） 的第 2/6 个文本块
# 2024-12-16 15:26:16,230 - INFO - 正在处理 歧义/歧见（mésentente） 的第 2/6 个文本块
# 2024-12-16 15:26:16,230 - INFO - 正在处理 歧义/歧见（mésentente） 的第 2/6 个文本块
# 2024-12-16 15:26:16,230 - INFO - 正在处理 歧义/歧见（mésentente） 的第 2/6 个文本块
# 2024-12-16 15:26:16,902 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:16,902 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:16,902 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:16,902 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:16,908 - INFO - 成功生成总结: 什么是歧义/歧见的根源？
# 2024-12-16 15:26:16,908 - INFO - 成功生成总结: 什么是歧义/歧见的根源？
# 2024-12-16 15:26:16,908 - INFO - 成功生成总结: 什么是歧义/歧见的根源？
# 2024-12-16 15:26:16,908 - INFO - 成功生成总结: 什么是歧义/歧见的根源？
# 2024-12-16 15:26:16,913 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_2.txt
# 2024-12-16 15:26:16,913 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_2.txt
# 2024-12-16 15:26:16,913 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_2.txt
# 2024-12-16 15:26:16,913 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_2.txt
# 2024-12-16 15:26:17,919 - INFO - 正在处理 歧义/歧见（mésentente） 的第 3/6 个文本块
# 2024-12-16 15:26:17,919 - INFO - 正在处理 歧义/歧见（mésentente） 的第 3/6 个文本块
# 2024-12-16 15:26:17,919 - INFO - 正在处理 歧义/歧见（mésentente） 的第 3/6 个文本块
# 2024-12-16 15:26:17,919 - INFO - 正在处理 歧义/歧见（mésentente） 的第 3/6 个文本块
# 2024-12-16 15:26:19,466 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:19,466 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:19,466 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:19,466 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:19,472 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其与政治和治安的关系？
# 2024-12-16 15:26:19,472 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其与政治和治安的关系？
# 2024-12-16 15:26:19,472 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其与政治和治安的关系？
# 2024-12-16 15:26:19,472 - INFO - 成功生成总结: 什么是歧义/歧见（mésentente）及其与政治和治安的关系？
# 2024-12-16 15:26:19,477 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_3.txt
# 2024-12-16 15:26:19,477 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_3.txt
# 2024-12-16 15:26:19,477 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_3.txt
# 2024-12-16 15:26:19,477 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_3.txt
# 2024-12-16 15:26:20,481 - INFO - 正在处理 歧义/歧见（mésentente） 的第 4/6 个文本块
# 2024-12-16 15:26:20,481 - INFO - 正在处理 歧义/歧见（mésentente） 的第 4/6 个文本块
# 2024-12-16 15:26:20,481 - INFO - 正在处理 歧义/歧见（mésentente） 的第 4/6 个文本块
# 2024-12-16 15:26:20,481 - INFO - 正在处理 歧义/歧见（mésentente） 的第 4/6 个文本块
# 2024-12-16 15:26:21,359 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:21,359 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:21,359 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:21,359 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:21,367 - INFO - 成功生成总结: 什么是歧义/歧见在政治中的作用？
# 2024-12-16 15:26:21,367 - INFO - 成功生成总结: 什么是歧义/歧见在政治中的作用？
# 2024-12-16 15:26:21,367 - INFO - 成功生成总结: 什么是歧义/歧见在政治中的作用？
# 2024-12-16 15:26:21,367 - INFO - 成功生成总结: 什么是歧义/歧见在政治中的作用？
# 2024-12-16 15:26:21,371 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_4.txt
# 2024-12-16 15:26:21,371 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_4.txt
# 2024-12-16 15:26:21,371 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_4.txt
# 2024-12-16 15:26:21,371 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_4.txt
# 2024-12-16 15:26:22,377 - INFO - 正在处理 歧义/歧见（mésentente） 的第 5/6 个文本块
# 2024-12-16 15:26:22,377 - INFO - 正在处理 歧义/歧见（mésentente） 的第 5/6 个文本块
# 2024-12-16 15:26:22,377 - INFO - 正在处理 歧义/歧见（mésentente） 的第 5/6 个文本块
# 2024-12-16 15:26:22,377 - INFO - 正在处理 歧义/歧见（mésentente） 的第 5/6 个文本块
# 2024-12-16 15:26:24,259 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:24,259 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:24,259 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:24,259 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:24,265 - INFO - 成功生成总结: 什么是歧义/歧见的本质及其与后现代语境中的叙事和语言游戏的关系？
# 2024-12-16 15:26:24,265 - INFO - 成功生成总结: 什么是歧义/歧见的本质及其与后现代语境中的叙事和语言游戏的关系？
# 2024-12-16 15:26:24,265 - INFO - 成功生成总结: 什么是歧义/歧见的本质及其与后现代语境中的叙事和语言游戏的关系？
# 2024-12-16 15:26:24,265 - INFO - 成功生成总结: 什么是歧义/歧见的本质及其与后现代语境中的叙事和语言游戏的关系？
# 2024-12-16 15:26:24,270 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_5.txt
# 2024-12-16 15:26:24,270 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_5.txt
# 2024-12-16 15:26:24,270 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_5.txt
# 2024-12-16 15:26:24,270 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_5.txt
# 2024-12-16 15:26:25,285 - INFO - 正在处理 歧义/歧见（mésentente） 的第 6/6 个文本块
# 2024-12-16 15:26:25,285 - INFO - 正在处理 歧义/歧见（mésentente） 的第 6/6 个文本块
# 2024-12-16 15:26:25,285 - INFO - 正在处理 歧义/歧见（mésentente） 的第 6/6 个文本块
# 2024-12-16 15:26:25,285 - INFO - 正在处理 歧义/歧见（mésentente） 的第 6/6 个文本块
# 2024-12-16 15:26:25,965 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:25,965 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:25,965 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:25,965 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:25,972 - INFO - 成功生成总结: 什么是歧义在朗西埃政治理论中的意义？
# 2024-12-16 15:26:25,972 - INFO - 成功生成总结: 什么是歧义在朗西埃政治理论中的意义？
# 2024-12-16 15:26:25,972 - INFO - 成功生成总结: 什么是歧义在朗西埃政治理论中的意义？
# 2024-12-16 15:26:25,972 - INFO - 成功生成总结: 什么是歧义在朗西埃政治理论中的意义？
# 2024-12-16 15:26:25,984 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_6.txt
# 2024-12-16 15:26:25,984 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_6.txt
# 2024-12-16 15:26:25,984 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_6.txt
# 2024-12-16 15:26:25,984 - INFO - 已保存文件: summaries\歧义歧见mésentente_chunk_6.txt
# 2024-12-16 15:26:26,993 - INFO - 正在处理关键词: 奇异性（singularity）
# 2024-12-16 15:26:26,993 - INFO - 正在处理关键词: 奇异性（singularity）
# 2024-12-16 15:26:26,993 - INFO - 正在处理关键词: 奇异性（singularity）
# 2024-12-16 15:26:26,993 - INFO - 正在处理关键词: 奇异性（singularity）
# 2024-12-16 15:26:26,996 - INFO - 正在处理 奇异性（singularity） 的第 1/5 个文本块
# 2024-12-16 15:26:26,996 - INFO - 正在处理 奇异性（singularity） 的第 1/5 个文本块
# 2024-12-16 15:26:26,996 - INFO - 正在处理 奇异性（singularity） 的第 1/5 个文本块
# 2024-12-16 15:26:26,996 - INFO - 正在处理 奇异性（singularity） 的第 1/5 个文本块
# 2024-12-16 15:26:27,754 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:27,754 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:27,754 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:27,754 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 15:26:27,762 - INFO - 成功生成总结: 奇异性（singularity）的起源和哲学内涵是什么？
# 2024-12-16 15:26:27,762 - INFO - 成功生成总结: 奇异性（singularity）的起源和哲学内涵是什么？
# 2024-12-16 15:26:27,762 - INFO - 成功生成总结: 奇异性（singularity）的起源和哲学内涵是什么？
# 2024-12-16 15:26:27,762 - INFO - 成功生成总结: 奇异性（singularity）的起源和哲学内涵是什么？
# 2024-12-16 15:26:27,766 - INFO - 已保存文件: summaries\奇异性singularity_chunk_1.txt
# 2024-12-16 15:26:27,766 - INFO - 已保存文件: summaries\奇异性singularity_chunk_1.txt
# 2024-12-16 16:22:30,840 - INFO - 正在处理 女性主义（Feminism） 的第 3/7 个文本块
# 2024-12-16 16:22:30,840 - INFO - 正在处理 女性主义（Feminism） 的第 3/7 个文本块
# 2024-12-16 16:22:30,840 - INFO - 正在处理 女性主义（Feminism） 的第 3/7 个文本块
# 2024-12-16 16:22:30,840 - INFO - 正在处理 女性主义（Feminism） 的第 3/7 个文本块
# 2024-12-16 16:22:32,234 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:32,234 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:32,234 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:32,234 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:32,250 - INFO - 成功生成总结: 女性主义运动的历史发展经历了哪两次高峰？
# 2024-12-16 16:22:32,250 - INFO - 成功生成总结: 女性主义运动的历史发展经历了哪两次高峰？
# 2024-12-16 16:22:32,250 - INFO - 成功生成总结: 女性主义运动的历史发展经历了哪两次高峰？
# 2024-12-16 16:22:32,250 - INFO - 成功生成总结: 女性主义运动的历史发展经历了哪两次高峰？
# 2024-12-16 16:22:32,257 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_3.txt
# 2024-12-16 16:22:32,257 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_3.txt
# 2024-12-16 16:22:32,257 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_3.txt
# 2024-12-16 16:22:32,257 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_3.txt
# 2024-12-16 16:22:33,262 - INFO - 正在处理 女性主义（Feminism） 的第 4/7 个文本块
# 2024-12-16 16:22:33,262 - INFO - 正在处理 女性主义（Feminism） 的第 4/7 个文本块
# 2024-12-16 16:22:33,262 - INFO - 正在处理 女性主义（Feminism） 的第 4/7 个文本块
# 2024-12-16 16:22:33,262 - INFO - 正在处理 女性主义（Feminism） 的第 4/7 个文本块
# 2024-12-16 16:22:34,284 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:34,284 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:34,284 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:34,284 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:34,290 - INFO - 成功生成总结: 女性主义的主要著作有哪些？
# 2024-12-16 16:22:34,290 - INFO - 成功生成总结: 女性主义的主要著作有哪些？
# 2024-12-16 16:22:34,290 - INFO - 成功生成总结: 女性主义的主要著作有哪些？
# 2024-12-16 16:22:34,290 - INFO - 成功生成总结: 女性主义的主要著作有哪些？
# 2024-12-16 16:22:34,294 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_4.txt
# 2024-12-16 16:22:34,294 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_4.txt
# 2024-12-16 16:22:34,294 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_4.txt
# 2024-12-16 16:22:34,294 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_4.txt
# 2024-12-16 16:22:35,299 - INFO - 正在处理 女性主义（Feminism） 的第 5/7 个文本块
# 2024-12-16 16:22:35,299 - INFO - 正在处理 女性主义（Feminism） 的第 5/7 个文本块
# 2024-12-16 16:22:35,299 - INFO - 正在处理 女性主义（Feminism） 的第 5/7 个文本块
# 2024-12-16 16:22:35,299 - INFO - 正在处理 女性主义（Feminism） 的第 5/7 个文本块
# 2024-12-16 16:22:36,238 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:36,238 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:36,238 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:36,238 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:36,244 - INFO - 成功生成总结: 第二次女性主义运动的主要目标和影响是什么？
# 2024-12-16 16:22:36,244 - INFO - 成功生成总结: 第二次女性主义运动的主要目标和影响是什么？
# 2024-12-16 16:22:36,244 - INFO - 成功生成总结: 第二次女性主义运动的主要目标和影响是什么？
# 2024-12-16 16:22:36,244 - INFO - 成功生成总结: 第二次女性主义运动的主要目标和影响是什么？
# 2024-12-16 16:22:36,259 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_5.txt
# 2024-12-16 16:22:36,259 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_5.txt
# 2024-12-16 16:22:36,259 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_5.txt
# 2024-12-16 16:22:36,259 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_5.txt
# 2024-12-16 16:22:37,273 - INFO - 正在处理 女性主义（Feminism） 的第 6/7 个文本块
# 2024-12-16 16:22:37,273 - INFO - 正在处理 女性主义（Feminism） 的第 6/7 个文本块
# 2024-12-16 16:22:37,273 - INFO - 正在处理 女性主义（Feminism） 的第 6/7 个文本块
# 2024-12-16 16:22:37,273 - INFO - 正在处理 女性主义（Feminism） 的第 6/7 个文本块
# 2024-12-16 16:22:37,952 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:37,952 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:37,952 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:37,952 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:37,956 - INFO - 成功生成总结: 女性主义的历史发展及其主要理论著作有哪些？
# 2024-12-16 16:22:37,956 - INFO - 成功生成总结: 女性主义的历史发展及其主要理论著作有哪些？
# 2024-12-16 16:22:37,956 - INFO - 成功生成总结: 女性主义的历史发展及其主要理论著作有哪些？
# 2024-12-16 16:22:37,956 - INFO - 成功生成总结: 女性主义的历史发展及其主要理论著作有哪些？
# 2024-12-16 16:22:37,961 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_6.txt
# 2024-12-16 16:22:37,961 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_6.txt
# 2024-12-16 16:22:37,961 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_6.txt
# 2024-12-16 16:22:37,961 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_6.txt
# 2024-12-16 16:22:38,976 - INFO - 正在处理 女性主义（Feminism） 的第 7/7 个文本块
# 2024-12-16 16:22:38,976 - INFO - 正在处理 女性主义（Feminism） 的第 7/7 个文本块
# 2024-12-16 16:22:38,976 - INFO - 正在处理 女性主义（Feminism） 的第 7/7 个文本块
# 2024-12-16 16:22:38,976 - INFO - 正在处理 女性主义（Feminism） 的第 7/7 个文本块
# 2024-12-16 16:22:39,903 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:39,903 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:39,903 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:39,903 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:39,910 - INFO - 成功生成总结: 女性主义有哪些主要流派及其特点？
# 2024-12-16 16:22:39,910 - INFO - 成功生成总结: 女性主义有哪些主要流派及其特点？
# 2024-12-16 16:22:39,910 - INFO - 成功生成总结: 女性主义有哪些主要流派及其特点？
# 2024-12-16 16:22:39,910 - INFO - 成功生成总结: 女性主义有哪些主要流派及其特点？
# 2024-12-16 16:22:39,914 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_7.txt
# 2024-12-16 16:22:39,914 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_7.txt
# 2024-12-16 16:22:39,914 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_7.txt
# 2024-12-16 16:22:39,914 - INFO - 已保存文件: summaries\女性主义Feminism_chunk_7.txt
# 2024-12-16 16:22:40,970 - INFO - 正在处理关键词: 批判理论（Critical Theory）
# 2024-12-16 16:22:40,970 - INFO - 正在处理关键词: 批判理论（Critical Theory）
# 2024-12-16 16:22:40,970 - INFO - 正在处理关键词: 批判理论（Critical Theory）
# 2024-12-16 16:22:40,970 - INFO - 正在处理关键词: 批判理论（Critical Theory）
# 2024-12-16 16:22:40,973 - INFO - 正在处理 批判理论（Critical Theory） 的第 1/6 个文本块
# 2024-12-16 16:22:40,973 - INFO - 正在处理 批判理论（Critical Theory） 的第 1/6 个文本块
# 2024-12-16 16:22:40,973 - INFO - 正在处理 批判理论（Critical Theory） 的第 1/6 个文本块
# 2024-12-16 16:22:40,973 - INFO - 正在处理 批判理论（Critical Theory） 的第 1/6 个文本块
# 2024-12-16 16:22:41,472 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:41,472 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:41,472 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:41,472 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:41,479 - INFO - 成功生成总结: 批判理论的形成和发展历程是什么？
# 2024-12-16 16:22:41,479 - INFO - 成功生成总结: 批判理论的形成和发展历程是什么？
# 2024-12-16 16:22:41,479 - INFO - 成功生成总结: 批判理论的形成和发展历程是什么？
# 2024-12-16 16:22:41,479 - INFO - 成功生成总结: 批判理论的形成和发展历程是什么？
# 2024-12-16 16:22:41,483 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_1.txt
# 2024-12-16 16:22:41,483 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_1.txt
# 2024-12-16 16:22:41,483 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_1.txt
# 2024-12-16 16:22:41,483 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_1.txt
# 2024-12-16 16:22:42,498 - INFO - 正在处理 批判理论（Critical Theory） 的第 2/6 个文本块
# 2024-12-16 16:22:42,498 - INFO - 正在处理 批判理论（Critical Theory） 的第 2/6 个文本块
# 2024-12-16 16:22:42,498 - INFO - 正在处理 批判理论（Critical Theory） 的第 2/6 个文本块
# 2024-12-16 16:22:42,498 - INFO - 正在处理 批判理论（Critical Theory） 的第 2/6 个文本块
# 2024-12-16 16:22:43,491 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:43,491 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:43,491 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:43,491 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:43,496 - INFO - 成功生成总结: 批判理论的起源和主要思想是什么？
# 2024-12-16 16:22:43,496 - INFO - 成功生成总结: 批判理论的起源和主要思想是什么？
# 2024-12-16 16:22:43,496 - INFO - 成功生成总结: 批判理论的起源和主要思想是什么？
# 2024-12-16 16:22:43,496 - INFO - 成功生成总结: 批判理论的起源和主要思想是什么？
# 2024-12-16 16:22:43,511 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_2.txt
# 2024-12-16 16:22:43,511 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_2.txt
# 2024-12-16 16:22:43,511 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_2.txt
# 2024-12-16 16:22:43,511 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_2.txt
# 2024-12-16 16:22:44,528 - INFO - 正在处理 批判理论（Critical Theory） 的第 3/6 个文本块
# 2024-12-16 16:22:44,528 - INFO - 正在处理 批判理论（Critical Theory） 的第 3/6 个文本块
# 2024-12-16 16:22:44,528 - INFO - 正在处理 批判理论（Critical Theory） 的第 3/6 个文本块
# 2024-12-16 16:22:44,528 - INFO - 正在处理 批判理论（Critical Theory） 的第 3/6 个文本块
# 2024-12-16 16:22:45,525 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:45,525 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:45,525 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:45,525 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:45,533 - INFO - 成功生成总结: 批判理论的内在批评方法是什么？
# 2024-12-16 16:22:45,533 - INFO - 成功生成总结: 批判理论的内在批评方法是什么？
# 2024-12-16 16:22:45,533 - INFO - 成功生成总结: 批判理论的内在批评方法是什么？
# 2024-12-16 16:22:45,533 - INFO - 成功生成总结: 批判理论的内在批评方法是什么？
# 2024-12-16 16:22:45,537 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_3.txt
# 2024-12-16 16:22:45,537 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_3.txt
# 2024-12-16 16:22:45,537 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_3.txt
# 2024-12-16 16:22:45,537 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_3.txt
# 2024-12-16 16:22:46,542 - INFO - 正在处理 批判理论（Critical Theory） 的第 4/6 个文本块
# 2024-12-16 16:22:46,542 - INFO - 正在处理 批判理论（Critical Theory） 的第 4/6 个文本块
# 2024-12-16 16:22:46,542 - INFO - 正在处理 批判理论（Critical Theory） 的第 4/6 个文本块
# 2024-12-16 16:22:46,542 - INFO - 正在处理 批判理论（Critical Theory） 的第 4/6 个文本块
# 2024-12-16 16:22:47,298 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:47,298 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:47,298 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:47,298 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:47,303 - INFO - 成功生成总结: 批判理论的跨学科研究特点是什么？
# 2024-12-16 16:22:47,303 - INFO - 成功生成总结: 批判理论的跨学科研究特点是什么？
# 2024-12-16 16:22:47,303 - INFO - 成功生成总结: 批判理论的跨学科研究特点是什么？
# 2024-12-16 16:22:47,303 - INFO - 成功生成总结: 批判理论的跨学科研究特点是什么？
# 2024-12-16 16:22:47,308 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_4.txt
# 2024-12-16 16:22:47,308 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_4.txt
# 2024-12-16 16:22:47,308 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_4.txt
# 2024-12-16 16:22:47,308 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_4.txt
# 2024-12-16 16:22:48,313 - INFO - 正在处理 批判理论（Critical Theory） 的第 5/6 个文本块
# 2024-12-16 16:22:48,313 - INFO - 正在处理 批判理论（Critical Theory） 的第 5/6 个文本块
# 2024-12-16 16:22:48,313 - INFO - 正在处理 批判理论（Critical Theory） 的第 5/6 个文本块
# 2024-12-16 16:22:48,313 - INFO - 正在处理 批判理论（Critical Theory） 的第 5/6 个文本块
# 2024-12-16 16:22:49,747 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:49,747 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:49,747 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:49,747 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:49,752 - INFO - 成功生成总结: 批判理论的主要观点和演变过程是什么？
# 2024-12-16 16:22:49,752 - INFO - 成功生成总结: 批判理论的主要观点和演变过程是什么？
# 2024-12-16 16:22:49,752 - INFO - 成功生成总结: 批判理论的主要观点和演变过程是什么？
# 2024-12-16 16:22:49,752 - INFO - 成功生成总结: 批判理论的主要观点和演变过程是什么？
# 2024-12-16 16:22:49,757 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_5.txt
# 2024-12-16 16:22:49,757 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_5.txt
# 2024-12-16 16:22:49,757 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_5.txt
# 2024-12-16 16:22:49,757 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_5.txt
# 2024-12-16 16:22:50,762 - INFO - 正在处理 批判理论（Critical Theory） 的第 6/6 个文本块
# 2024-12-16 16:22:50,762 - INFO - 正在处理 批判理论（Critical Theory） 的第 6/6 个文本块
# 2024-12-16 16:22:50,762 - INFO - 正在处理 批判理论（Critical Theory） 的第 6/6 个文本块
# 2024-12-16 16:22:50,762 - INFO - 正在处理 批判理论（Critical Theory） 的第 6/6 个文本块
# 2024-12-16 16:22:51,811 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:51,811 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:51,811 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:51,811 - INFO - HTTP Request: POST https://open.bigmodel.cn/api/paas/v4/chat/completions "HTTP/1.1 200 OK"
# 2024-12-16 16:22:51,816 - INFO - 成功生成总结: 哈贝马斯与阿多诺在批判理论上的关系和分歧是什么？
# 2024-12-16 16:22:51,816 - INFO - 成功生成总结: 哈贝马斯与阿多诺在批判理论上的关系和分歧是什么？
# 2024-12-16 16:22:51,816 - INFO - 成功生成总结: 哈贝马斯与阿多诺在批判理论上的关系和分歧是什么？
# 2024-12-16 16:22:51,816 - INFO - 成功生成总结: 哈贝马斯与阿多诺在批判理论上的关系和分歧是什么？
# 2024-12-16 16:22:51,820 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_6.txt
# 2024-12-16 16:22:51,820 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_6.txt
# 2024-12-16 16:22:51,820 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_6.txt
# 2024-12-16 16:22:51,820 - INFO - 已保存文件: summaries\批判理论Critical Theory_chunk_6.txt
# 2024-12-16 16:22:53,000 - INFO - 处理完成，结果已保存至: output_alpaca.json
# 2024-12-16 16:22:53,000 - INFO - 处理完成，结果已保存至: output_alpaca.json
# 2024-12-16 16:22:53,000 - INFO - 处理完成，结果已保存至: output_alpaca.json
# 2024-12-16 16:22:53,000 - INFO - 处理完成，结果已保存至: output_alpaca.json
